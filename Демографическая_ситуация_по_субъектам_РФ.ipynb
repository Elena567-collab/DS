# %% [markdown]
# **Тема: "Демографическая ситуация по субъектам РФ"**
#
#
#  **Описание проекта:**
#
#
#  Перед нами представлен набор данных, который несет в себе информацию о численности экономически активного населения, безработных, уровне безработицы и сопоставляет все эти показатели между различными возрастными группами по субьектам РФ за период 2001-2019 гг.

# %% [markdown]
# **Цель проекта:**
#
# 1. Определить на какой территории минимальный и максимальный процент безработных за весь период времени.
# 2. Проверить гипотезу: в каждой из возрастных категорий среднее значение занятых идентично средниму значению безработных
# 3. Проверить гипотезу: среднее значение безработных (в возрасте от 40 до 49 лет) в Брянской области одинаково со средним значением безработных возрасте до 20 лет
# 4. Проверить гипотеза: средний показатель безработицы в 2009 и 2019 году одинаков

# %% [markdown]
# **План анализа данных:**
#
# 1. Изучение общей информации
# 2. Предобработка данных
# 2.1. Проверка корректности наименований колонок;
# 2.2. Проверка и обработка пропущенных значений;
# 2.3. Проверка и обработка дубликатов;
# 2.4. Проверка и обработка типов данных;
# 3. Исследовательский анализ данных
# 3.1. Построение гистограммы с количеством безработных и занятых (общему количеству и по конкретной территории);
# 3.2. Определение на какой территории минимальный и максимальный процент безработных;
# 3.3. Вычислить среднее число безработных и занятых (по каждой территории)
# 3.4. Выделить ТОП-5 территорий по безработным и занятым
# 3.5. Построение столбчатой диаграммы с количеством занятых (по возрастным категориям)
# 3.6. Построение столбчатой диаграммы с количеством безработных (по возрастным категориям)
# 4. Проверка гипотез
# 4.1. Гипотеза: в каждой из возрастных категорий среднее значение занятых идентично среднему значению безработных
# 4.3. Гипотеза: среднее значение безработных (в возрасте от 40 до 49 лет) в Брянской области одинаково со средним значением безработных возрасте до 20 лет
# 4.4. Гипотеза: средний показатель безработицы в 2009 и 2019 одинаков
# 5. Дополнительная информация
# 5.1. Подготовка документации по библиотекам
# 6. Общий вывод

# %% [markdown]
# **Описание данных:**
#
# territory - наименование территории по ОКАТО
# num_economactivepopulation_all - численность экономически активного населения - всего
# employed_num_all - занятые в экономике
# unemployed_num_all - безработные
# eactivity_lvl - уровень экономической активности
# employment_lvl - уровень занятости
# unemployment_lvl - уровень безработицы
# dis_unagegroup_to20 - распределение безработных в возрасте до 20 лет по регионам РФ
# dis_unagegroup_20-29 - распределение безработных в возрасте от 20 до 29 лет по регионам РФ
# dis_unagegroup_30-39 - распределение безработных в возрасте от 30 до 39 лет по регионам РФ
# dis_unagegroup_40-49 - распределение безработных в возрасте от 40 до 49 лет по регионам РФ
# dis_unagegroup_50-59 - распределение безработных в возрасте от 50 до 59 лет по регионам РФ
# dis_unagegroup_60older - распределение безработных в возрасте 60 и более лет по регионам РФ
# dis_emagegroup_to20 - распределение занятых в экономике в возрасте до 20 лет по регионам РФ
# dis_emagegroup_20-29 - распределение занятых в экономике в возрасте от 20 до 29 лет по регионам РФ
# dis_emagegroup_30-39 - распределение занятых в экономике в возрасте от 30 до 39 лет по регионам РФ
# dis_emagegroup_40-49 - распределение занятых в экономике в возрасте от 40 до 49 лет по регионам РФ
# dis_emagegroup_50-59 - распределение занятых в экономике в возрасте от 50 до 59 лет по регионам РФ
# dis_emagegroup_60older - распределение занятых в экономике в возрасте 60 и более лет по регионам РФ
# num_unagegroup_to20 - численность безработных в возрасте до 20 лет по регионам РФ
# num_unagegroup_20-29 - численность безработных в возрасте от 20 до 29 лет по регионам РФ
# num_unagegroup_30-39 - численность безработных в возрасте от 30 до 39 лет по регионам РФ
# num_unagegroup_40-49 - численность безработных в возрасте от 40 до 49 лет по регионам РФ
# num_unagegroup_50-59 - численность безработных в возрасте от 50 до 59 лет по регионам РФ
# num_unagegroup_60older - численность безработных в возрасте 60 и более лет по регионам РФ
# num_emagegroup_to20 - численность занятых в экономике регионов РФ в возрасте до 20 лет
# num_emagegroup_20-29 - численность занятых в экономике регионов РФ в возрасте от 20 до 29 лет
# num_emagegroup_30-39 - численность занятых в экономике регионов РФ в возрасте от 30 до 39 лет
# num_emagegroup_40-49 - численность занятых в экономике регионов РФ в возрасте от 40 до 49 лет
# num_emagegroup_50-59 - численность занятых в экономике регионов РФ в возрасте от 50 до 59 лет
# num_emagegroup_60older - численность занятых в экономике регионов РФ в возрасте 60 и более лет
# year - отчетный год

# %% [markdown]
# # **Изучение общей информации**
# Откроем файл с данными и изучим общую информацию

# %%
# импортируем необходимые библиотеки
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
from scipy import stats as st

import warnings
warnings.filterwarnings('ignore')

# для полноценной работы со строками мы уберем ограничение строк и столбцов в отображении
pd.set_option('display.max_rows', None)
pd.set_option('display.max_columns', None)

# %%
# присвоим переменной data нашу таблицу
data = pd.read_csv('/content/data.csv')
# выведем первые пять строки нашей таблицы
data.head()
# Out:
#                        territory  num_economactivepopulation_all  \
# 0           Российская Федерация                         70816.1
# 1  Центральный федеральный округ                         18337.9
# 2           Белгородская область                           737.9
# 3               Брянская область                           653.5
# 4           Владимирская область                           808.9
#
#    employed_num_all  unemployed_num_all  eactivity_lvl  employment_lvl  \
# 0           64400.1              6416.0           64.2            58.4
# 1           17181.9              1156.0           64.6            60.5
# 2             689.6                48.3           65.4            61.1
# 3             588.1                65.3           61.0            54.9
# 4             728.4                80.5           65.4            58.9
#
#    unemployment_lvl  dis_unagegroup_to20  dis_unagegroup_20-29  \
# 0               9.1                  8.2                  30.7
# 1               6.3                  7.9                  29.8
# 2               6.5                  6.0                  43.4
# 3              10.0                  5.9                  33.3
# 4               9.9                 13.2                  32.4
#
#    dis_unagegroup_30-39  dis_unagegroup_40-49  dis_unagegroup_50-59  \
# 0                  24.8                  24.2                   9.7
# 1                  24.6                  24.4                  10.4
# 2                  17.2                  19.4                   8.9
# 3                  28.0                  23.6                   8.2
# 4                  21.4                  25.0                   5.0
#
#    dis_unagegroup_60older  dis_emagegroup_to20  dis_emagegroup_20-29  \
# 0                     2.4                  2.2                  21.8
# 1                     2.9                  1.7                  20.1
# 2                     5.0                  1.9                  21.5
# 3                     1.0                  2.8                  23.1
# 4                     3.1                  2.3                  21.6
#
#    dis_emagegroup_30-39  dis_emagegroup_40-49  dis_emagegroup_50-59  \
# 0                  26.5                  30.7                  14.6
# 1                  25.9                  30.6                  16.2
# 2                  27.1                  30.4                  12.4
# 3                  27.1                  30.7                  12.4
# 4                  25.7                  30.4                  15.4
#
#    dis_emagegroup_60older  num_unagegroup_to20  num_unagegroup_20-29  \
# 0                     4.4                526.1                1969.7
# 1                     5.5                 91.3                 344.5
# 2                     6.7                  2.9                  21.0
# 3                     3.9                  3.9                  21.7
# 4                     4.6                 10.6                  26.1
#
#    num_unagegroup_30-39  num_unagegroup_40-49  num_unagegroup_50-59  \
# 0                1591.2                1552.7                 622.4
# 1                 284.4                 282.1                 120.2
# 2                   8.3                   9.4                   4.3
# 3                  18.3                  15.4                   5.4
# 4                  17.2                  20.1                   4.0
#
#    num_unagegroup_60older  num_emagegroup_to20  num_emagegroup_20-29  \
# 0                   154.0               1416.8               14039.2
# 1                    33.5                292.1                3453.6
# 2                     2.4                 13.1                 148.3
# 3                     0.7                 16.5                 135.9
# 4                     2.5                 16.8                 157.3
#
#    num_emagegroup_30-39  num_emagegroup_40-49  num_emagegroup_50-59  \
# 0               17066.0               19770.8                9402.4
# 1                4450.1                5257.7                2783.5
# 2                 186.9                 209.6                  85.5
# 3                 159.4                 180.5                  72.9
# 4                 187.2                 221.4                 112.2
#
#    num_emagegroup_60older  year
# 0                  2833.6  2001
# 1                   945.0  2001
# 2                    46.2  2001
# 3                    22.9  2001
# 4                    33.5  2001

# %% [markdown]
# Посмотрим на информацию по нашим столбцам.
#
# С помощью метода info() мы можем увидеть типы каждого из столбцов.

# %%
# проверяем типы столбцов
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 831 entries, 0 to 830
# Data columns (total 32 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   territory                       831 non-null    object
#  1   num_economactivepopulation_all  829 non-null    float64
#  2   employed_num_all                829 non-null    float64
#  3   unemployed_num_all              829 non-null    float64
#  4   eactivity_lvl                   829 non-null    float64
#  5   employment_lvl                  829 non-null    float64
#  6   unemployment_lvl                829 non-null    float64
#  7   dis_unagegroup_to20             827 non-null    float64
#  8   dis_unagegroup_20-29            829 non-null    float64
#  9   dis_unagegroup_30-39            829 non-null    float64
#  10  dis_unagegroup_40-49            829 non-null    float64
#  11  dis_unagegroup_50-59            829 non-null    float64
#  12  dis_unagegroup_60older          815 non-null    float64
#  13  dis_emagegroup_to20             827 non-null    float64
#  14  dis_emagegroup_20-29            829 non-null    float64
#  15  dis_emagegroup_30-39            829 non-null    float64
#  16  dis_emagegroup_40-49            829 non-null    float64
#  17  dis_emagegroup_50-59            829 non-null    float64
#  18  dis_emagegroup_60older          829 non-null    float64
#  19  num_unagegroup_to20             828 non-null    float64
#  20  num_unagegroup_20-29            829 non-null    float64
#  21  num_unagegroup_30-39            829 non-null    float64
#  22  num_unagegroup_40-49            829 non-null    float64
#  23  num_unagegroup_50-59            829 non-null    float64
#  24  num_unagegroup_60older          817 non-null    float64
#  25  num_emagegroup_to20             828 non-null    float64
#  26  num_emagegroup_20-29            829 non-null    float64
#  27  num_emagegroup_30-39            829 non-null    float64
#  28  num_emagegroup_40-49            829 non-null    float64
#  29  num_emagegroup_50-59            829 non-null    float64
#  30  num_emagegroup_60older          829 non-null    float64
#  31  year                            831 non-null    int64
# dtypes: float64(30), int64(1), object(1)
# memory usage: 207.9+ KB

# %% [markdown]
# Мы ознакомились с данными, с которыми в дальнейшем будем работать. Теперь перейдем к самой обработке.

# %% [markdown]
# **Предобработка данных**
#
# **Проверка корректности наименований колонок**

# %%
# отобразим названия колонок
list(data.columns)
# Out:
# ['territory',
#  'num_economactivepopulation_all',
#  'employed_num_all',
#  'unemployed_num_all',
#  'eactivity_lvl',
#  'employment_lvl',
#  'unemployment_lvl',
#  'dis_unagegroup_to20',
#  'dis_unagegroup_20-29',
#  'dis_unagegroup_30-39',
#  'dis_unagegroup_40-49',
#  'dis_unagegroup_50-59',
#  'dis_unagegroup_60older',
#  'dis_emagegroup_to20',
#  'dis_emagegroup_20-29',
#  'dis_emagegroup_30-39',
#  'dis_emagegroup_40-49',
#  'dis_emagegroup_50-59',
#  'dis_emagegroup_60older',
#  'num_unagegroup_to20',
#  'num_unagegroup_20-29',
#  'num_unagegroup_30-39',
#  'num_unagegroup_40-49',
#  'num_unagegroup_50-59',
#  'num_unagegroup_60older',
#  'num_emagegroup_to20',
#  'num_emagegroup_20-29',
#  'num_emagegroup_30-39',
#  'num_emagegroup_40-49',
#  'num_emagegroup_50-59',
#  'num_emagegroup_60older',
#  'year']

# %%
data.rename(columns = {
    'territory' : 'Территория',
    'num_economactivepopulation_all' : 'Численность населения',
    'employed_num_all' : 'Занятые в экономике',
    'unemployed_num_all' : 'Безработные',
    'eactivity_lvl' : 'Уровень экономической активности',
    'employment_lvl' : 'Уровень занятости',
    'unemployment_lvl' : 'Уровень безработицы',
    'dis_unagegroup_to20' : 'Распределение безработных (до 20 лет)',
    'dis_unagegroup_20-29' : 'Распределение безработных (от 20 до 29 лет)',
    'dis_unagegroup_30-39' : 'Распределение безработных (от 30 до 39 лет)',
    'dis_unagegroup_40-49' : 'Распределение безработных (от 40 до 49 лет)',
    'dis_unagegroup_50-59' : 'Распределение безработных (от 50 до 59 лет)',
    'dis_unagegroup_60older' : 'Распределение безработных (60 и более лет)',
    'dis_emagegroup_to20' : 'Распределение занятых (до 20 лет)',
    'dis_emagegroup_20-29' : 'Распределение занятых (от 20 до 29 лет)',
    'dis_emagegroup_30-39' : 'Распределение занятых (от 30 до 39 лет)',
    'dis_emagegroup_40-49' : 'Распределение занятых (от 40 до 49 лет)',
    'dis_emagegroup_50-59' : 'Распределение занятых (от 50 до 59 лет)',
    'dis_emagegroup_60older' : 'Распределение занятых (60 и более лет)',
    'num_unagegroup_to20' : 'Численность безработных (до 20 лет)',
    'num_unagegroup_20-29' : 'Численность безработных (от 20 до 29 лет)',
    'num_unagegroup_30-39' : 'Численность безработных (от 30 до 39 лет)',
    'num_unagegroup_40-49' : 'Численность безработных (от 40 до 49 лет)',
    'num_unagegroup_50-59' : 'Численность безработных (от 50 до 59 лет)',
    'num_unagegroup_60older' : 'Численность безработных (60 и более лет)',
    'num_emagegroup_to20' : 'Численность занятых (до 20 лет)',
    'num_emagegroup_20-29' : 'Численность занятых (от 20 до 29 лет)',
    'num_emagegroup_30-39' : 'Численность занятых (от 30 до 39 лет)',
    'num_emagegroup_40-49' : 'Численность занятых (от 40 до 49 лет)',
    'num_emagegroup_50-59' : 'Численность занятых (от 50 до 59 лет)',
    'num_emagegroup_60older' : 'Численность занятых (60 и более лет)',
    'year' : 'Год',
}, inplace = True)

# %% [markdown]
# Далее проверим как изменились наши столбцы.

# %%
list(data.columns)
# Out:
# ['Территория',
#  'Численность населения',
#  'Занятые в экономике',
#  'Безработные',
#  'Уровень экономической активности',
#  'Уровень занятости',
#  'Уровень безработицы',
#  'Распределение безработных (до 20 лет)',
#  'Распределение безработных (от 20 до 29 лет)',
#  'Распределение безработных (от 30 до 39 лет)',
#  'Распределение безработных (от 40 до 49 лет)',
#  'Распределение безработных (от 50 до 59 лет)',
#  'Распределение безработных (60 и более лет)',
#  'Распределение занятых (до 20 лет)',
#  'Распределение занятых (от 20 до 29 лет)',
#  'Распределение занятых (от 30 до 39 лет)',
#  'Распределение занятых (от 40 до 49 лет)',
#  'Распределение занятых (от 50 до 59 лет)',
#  'Распределение занятых (60 и более лет)',
#  'Численность безработных (до 20 лет)',
#  'Численность безработных (от 20 до 29 лет)',
#  'Численность безработных (от 30 до 39 лет)',
#  'Численность безработных (от 40 до 49 лет)',
#  'Численность безработных (от 50 до 59 лет)',
#  'Численность безработных (60 и более лет)',
#  'Численность занятых (до 20 лет)',
#  'Численность занятых (от 20 до 29 лет)',
#  'Численность занятых (от 30 до 39 лет)',
#  'Численность занятых (от 40 до 49 лет)',
#  'Численность занятых (от 50 до 59 лет)',
#  'Численность занятых (60 и более лет)',
#  'Год']

# %% [markdown]
# Теперь колонки имеют более читабельный вид. Перейдем к обработке пропусков.

# %% [markdown]
# П**роверка и обработка пропущенных значений**
#
#
# Перед тем, как мы будем делать обработку - нам необходимо проверить количество пропусков в каждом столбце.

# %%
# проверим количество пропусков (метод isnull()) и посчитаем сумму (метод sum())
data.isnull().sum()
# Out:
# Территория                                      0
# Численность населения                           2
# Занятые в экономике                             2
# Безработные                                     2
# Уровень экономической активности                2
# Уровень занятости                               2
# Уровень безработицы                             2
# Распределение безработных (до 20 лет)           4
# Распределение безработных (от 20 до 29 лет)     2
# Распределение безработных (от 30 до 39 лет)     2
# Распределение безработных (от 40 до 49 лет)     2
# Распределение безработных (от 50 до 59 лет)     2
# Распределение безработных (60 и более лет)     16
# Распределение занятых (до 20 лет)               4
# Распределение занятых (от 20 до 29 лет)         2
# Распределение занятых (от 30 до 39 лет)         2
# Распределение занятых (от 40 до 49 лет)         2
# Распределение занятых (от 50 до 59 лет)         2
# Распределение занятых (60 и более лет)          2
# Численность безработных (до 20 лет)             3
# Численность безработных (от 20 до 29 лет)       2
# Численность безработных (от 30 до 39 лет)       2
# Численность безработных (от 40 до 49 лет)       2
# Численность безработных (от 50 до 59 лет)       2
# Численность безработных (60 и более лет)       14
# Численность занятых (до 20 лет)                 3
# Численность занятых (от 20 до 29 лет)           2
# Численность занятых (от 30 до 39 лет)           2
# Численность занятых (от 40 до 49 лет)           2
# Численность занятых (от 50 до 59 лет)           2
# Численность занятых (60 и более лет)            2
# Год                                             0
# dtype: int64

# %% [markdown]
# Мы видим в каждой ячейке пропущенные значения, кроме "Территории" и "Год". В большинстве столбцов пропущенных значений (2) и мы можем предположить, что две строки полностью пустые. Но для того, чтобы точно определиться мы это проверим.

# %%
# проверяем пропуски, во всех ли столбцах они есть? и предпримем необходимые действия
data[pd.isnull(data).any(axis=1)]
# Out:
#                           Территория  Численность населения  \
# 26           Калининградская область                  446.3
# 30                 Псковская область                  374.6
# 35              Республика Ингушетия                  145.4
# 38   Карачаево-Черкесская Республика                  184.8
# 40              Чеченская Республика                    NaN
# 49               Республика Мордовия                  432.1
# 126             Республика Ингушетия                  139.6
# 131             Чеченская Республика                    NaN
# 251                 Республика Алтай                   98.4
# 468                Орловская область                  394.1
# 471               Тамбовская область                  533.2
# 523  Ямало-Ненецкий автономный округ                  324.8
# 528                  Республика Тыва                  122.0
# 547       Чукотский автономный округ                   33.2
# 655                Орловская область                  378.5
# 676                Республика Адыгея                  200.1
# 683                   г. Севастополь                  202.0
# 687  Кабардино-Балкарская Республика                  433.2
# 752               Тамбовская область                  499.5
# 806  Ямало-Ненецкий автономный округ                  315.5
# 826                 Амурская область                  407.8
# 830       Чукотский автономный округ                   31.1
#
#      Занятые в экономике  Безработные  Уровень экономической активности  \
# 26                 403.6         42.8                              60.2
# 30                 335.9         38.7                              61.8
# 35                  94.7         50.8                              54.9
# 38                 150.5         34.3                              58.8
# 40                   NaN          NaN                               NaN
# 49                 386.9         45.2                              61.9
# 126                 74.9         64.7                              45.6
# 131                  NaN          NaN                               NaN
# 251                 89.5          8.9                              66.9
# 468                371.1         23.0                              65.6
# 471                508.6         24.6                              63.7
# 523                314.5         10.3                              77.0
# 528                 98.5         23.5                              57.7
# 547                 32.1          1.1                              83.1
# 655                353.9         24.6                              65.9
# 676                182.5         17.6                              60.2
# 683                192.8          9.2                              63.8
# 687                387.9         45.3                              68.3
# 752                479.9         19.6                              56.3
# 806                309.4          6.1                              75.9
# 826                385.9         21.9                              63.3
# 830                 30.0          1.2                              80.5
#
#      Уровень занятости  Уровень безработицы  \
# 26                54.5                  9.6
# 30                55.5                 10.3
# 35                35.8                 34.9
# 38                47.9                 18.6
# 40                 NaN                  NaN
# 49                55.4                 10.5
# 126               24.5                 46.3
# 131                NaN                  NaN
# 251               61.0                  8.8
# 468               61.8                  5.8
# 471               60.8                  4.6
# 523               74.6                  3.2
# 528               46.6                 19.3
# 547               80.4                  3.3
# 655               61.7                  6.5
# 676               54.9                  8.8
# 683               60.9                  4.6
# 687               61.2                 10.5
# 752               54.1                  3.9
# 806               74.4                  1.9
# 826               59.9                  5.4
# 830               77.4                  3.8
#
#      Распределение безработных (до 20 лет)  \
# 26                                     5.5
# 30                                     6.0
# 35                                     0.7
# 38                                     2.1
# 40                                     NaN
# 49                                     2.7
# 126                                    5.3
# 131                                    NaN
# 251                                    NaN
# 468                                    2.4
# 471                                    2.3
# 523                                    6.2
# 528                                    2.6
# 547                                    5.0
# 655                                    2.7
# 676                                    1.1
# 683                                    NaN
# 687                                    1.8
# 752                                    1.6
# 806                                    2.3
# 826                                    0.8
# 830                                    1.3
#
#      Распределение безработных (от 20 до 29 лет)  \
# 26                                          34.0
# 30                                          26.9
# 35                                          38.0
# 38                                          36.9
# 40                                           NaN
# 49                                          36.8
# 126                                         44.6
# 131                                          NaN
# 251                                         40.6
# 468                                         31.1
# 471                                         29.1
# 523                                         54.4
# 528                                         44.2
# 547                                         36.9
# 655                                         34.8
# 676                                         26.8
# 683                                         32.9
# 687                                         39.0
# 752                                         25.9
# 806                                         52.2
# 826                                         35.9
# 830                                         49.0
#
#      Распределение безработных (от 30 до 39 лет)  \
# 26                                          18.9
# 30                                          25.6
# 35                                          24.1
# 38                                          36.2
# 40                                           NaN
# 49                                          30.3
# 126                                         28.7
# 131                                          NaN
# 251                                         19.4
# 468                                         24.3
# 471                                         23.7
# 523                                         17.1
# 528                                         29.3
# 547                                         26.9
# 655                                         29.2
# 676                                         31.6
# 683                                         22.2
# 687                                         29.9
# 752                                         32.4
# 806                                         24.6
# 826                                         29.2
# 830                                         32.2
#
#      Распределение безработных (от 40 до 49 лет)  \
# 26                                          25.1
# 30                                          32.3
# 35                                          33.0
# 38                                          16.8
# 40                                           NaN
# 49                                          21.9
# 126                                         16.7
# 131                                          NaN
# 251                                         30.4
# 468                                         26.8
# 471                                         25.5
# 523                                          8.6
# 528                                         19.0
# 547                                         21.7
# 655                                         18.7
# 676                                         25.7
# 683                                         18.2
# 687                                         17.3
# 752                                         21.7
# 806                                          5.9
# 826                                         18.9
# 830                                         12.7
#
#      Распределение безработных (от 50 до 59 лет)  \
# 26                                          16.5
# 30                                           9.3
# 35                                           3.8
# 38                                           8.0
# 40                                           NaN
# 49                                           8.3
# 126                                          4.5
# 131                                          NaN
# 251                                          9.7
# 468                                         15.4
# 471                                         19.3
# 523                                         13.8
# 528                                          4.7
# 547                                          5.8
# 655                                         14.7
# 676                                         14.8
# 683                                         20.3
# 687                                         12.1
# 752                                         18.4
# 806                                         15.0
# 826                                         14.9
# 830                                          4.8
#
#      Распределение безработных (60 и более лет)  \
# 26                                          NaN
# 30                                          NaN
# 35                                          0.4
# 38                                          NaN
# 40                                          NaN
# 49                                          NaN
# 126                                         0.2
# 131                                         NaN
# 251                                         NaN
# 468                                         NaN
# 471                                         NaN
# 523                                         NaN
# 528                                         0.2
# 547                                         3.7
# 655                                         NaN
# 676                                         NaN
# 683                                         6.4
# 687                                         NaN
# 752                                         NaN
# 806                                         NaN
# 826                                         0.2
# 830                                         NaN
#
#      Распределение занятых (до 20 лет)  \
# 26                                 0.9
# 30                                 2.2
# 35                                 NaN
# 38                                 3.5
# 40                                 NaN
# 49                                 1.7
# 126                                NaN
# 131                                NaN
# 251                                1.6
# 468                                0.7
# 471                                0.5
# 523                                0.2
# 528                                0.7
# 547                                0.7
# 655                                0.3
# 676                                0.3
# 683                                0.3
# 687                                1.7
# 752                                0.3
# 806                                0.2
# 826                                1.5
# 830                                0.1
#
#      Распределение занятых (от 20 до 29 лет)  \
# 26                                      18.8
# 30                                      22.5
# 35                                      19.8
# 38                                      19.7
# 40                                       NaN
# 49                                      20.4
# 126                                     13.1
# 131                                      NaN
# 251                                     26.6
# 468                                     22.3
# 471                                     20.9
# 523                                     21.3
# 528                                     24.1
# 547                                     21.1
# 655                                     20.3
# 676                                     20.9
# 683                                     19.9
# 687                                     22.3
# 752                                     17.3
# 806                                     14.6
# 826                                     21.0
# 830                                     12.7
#
#      Распределение занятых (от 30 до 39 лет)  \
# 26                                      29.2
# 30                                      26.2
# 35                                      45.6
# 38                                      25.7
# 40                                       NaN
# 49                                      28.3
# 126                                     39.1
# 131                                      NaN
# 251                                     25.5
# 468                                     25.2
# 471                                     25.1
# 523                                     30.0
# 528                                     30.6
# 547                                     25.4
# 655                                     25.5
# 676                                     29.2
# 683                                     29.0
# 687                                     24.9
# 752                                     27.2
# 806                                     32.8
# 826                                     29.1
# 830                                     28.3
#
#      Распределение занятых (от 40 до 49 лет)  \
# 26                                      29.2
# 30                                      30.6
# 35                                      27.4
# 38                                      30.3
# 40                                       NaN
# 49                                      33.3
# 126                                     32.8
# 131                                      NaN
# 251                                     26.7
# 468                                     24.1
# 471                                     25.4
# 523                                     27.1
# 528                                     27.1
# 547                                     24.4
# 655                                     24.4
# 676                                     26.1
# 683                                     24.1
# 687                                     22.8
# 752                                     25.7
# 806                                     28.8
# 826                                     25.2
# 830                                     26.4
#
#      Распределение занятых (от 50 до 59 лет)  \
# 26                                      16.8
# 30                                      14.4
# 35                                       5.0
# 38                                      13.0
# 40                                       NaN
# 49                                      13.2
# 126                                     13.0
# 131                                      NaN
# 251                                     18.0
# 468                                     22.7
# 471                                     24.2
# 523                                     20.0
# 528                                     14.8
# 547                                     22.5
# 655                                     22.5
# 676                                     20.8
# 683                                     19.9
# 687                                     21.5
# 752                                     24.1
# 806                                     21.6
# 826                                     18.1
# 830                                     23.8
#
#      Распределение занятых (60 и более лет)  \
# 26                                      5.2
# 30                                      4.2
# 35                                      2.3
# 38                                      7.7
# 40                                      NaN
# 49                                      3.2
# 126                                     2.0
# 131                                     NaN
# 251                                     1.5
# 468                                     5.0
# 471                                     4.0
# 523                                     1.4
# 528                                     2.7
# 547                                     5.9
# 655                                     6.9
# 676                                     2.6
# 683                                     6.8
# 687                                     6.8
# 752                                     5.4
# 806                                     1.9
# 826                                     5.1
# 830                                     8.7
#
#      Численность безработных (до 20 лет)  \
# 26                                   2.4
# 30                                   2.3
# 35                                   0.4
# 38                                   0.7
# 40                                   NaN
# 49                                   1.2
# 126                                  3.4
# 131                                  NaN
# 251                                  0.0
# 468                                  0.6
# 471                                  0.6
# 523                                  0.6
# 528                                  0.6
# 547                                  0.1
# 655                                  0.7
# 676                                  0.2
# 683                                  NaN
# 687                                  0.8
# 752                                  0.3
# 806                                  0.1
# 826                                  0.2
# 830                                  0.0
#
#      Численность безработных (от 20 до 29 лет)  \
# 26                                        14.6
# 30                                        10.4
# 35                                        19.3
# 38                                        12.7
# 40                                         NaN
# 49                                        16.6
# 126                                       28.9
# 131                                        NaN
# 251                                        3.6
# 468                                        7.1
# 471                                        7.2
# 523                                        5.6
# 528                                       10.4
# 547                                        0.4
# 655                                        8.5
# 676                                        4.7
# 683                                        3.0
# 687                                       17.7
# 752                                        5.1
# 806                                        3.2
# 826                                        7.9
# 830                                        0.6
#
#      Численность безработных (от 30 до 39 лет)  \
# 26                                         8.1
# 30                                         9.9
# 35                                        12.2
# 38                                        12.4
# 40                                         NaN
# 49                                        13.7
# 126                                       18.6
# 131                                        NaN
# 251                                        1.7
# 468                                        5.6
# 471                                        5.8
# 523                                        1.8
# 528                                        6.9
# 547                                        0.3
# 655                                        7.2
# 676                                        5.5
# 683                                        2.0
# 687                                       13.6
# 752                                        6.4
# 806                                        1.5
# 826                                        6.4
# 830                                        0.4
#
#      Численность безработных (от 40 до 49 лет)  \
# 26                                        10.7
# 30                                        12.5
# 35                                        16.8
# 38                                         5.8
# 40                                         NaN
# 49                                         9.9
# 126                                       10.8
# 131                                        NaN
# 251                                        2.7
# 468                                        6.2
# 471                                        6.3
# 523                                        0.9
# 528                                        4.5
# 547                                        0.2
# 655                                        4.6
# 676                                        4.5
# 683                                        1.7
# 687                                        7.8
# 752                                        4.2
# 806                                        0.4
# 826                                        4.1
# 830                                        0.1
#
#      Численность безработных (от 50 до 59 лет)  \
# 26                                         7.1
# 30                                         3.6
# 35                                         1.9
# 38                                         2.7
# 40                                         NaN
# 49                                         3.8
# 126                                        2.9
# 131                                        NaN
# 251                                        0.9
# 468                                        3.5
# 471                                        4.8
# 523                                        1.4
# 528                                        1.1
# 547                                        0.1
# 655                                        3.6
# 676                                        2.6
# 683                                        1.9
# 687                                        5.5
# 752                                        3.6
# 806                                        0.9
# 826                                        3.3
# 830                                        0.1
#
#      Численность безработных (60 и более лет)  \
# 26                                        0.0
# 30                                        0.0
# 35                                        0.2
# 38                                        0.0
# 40                                        NaN
# 49                                        0.0
# 126                                       0.1
# 131                                       NaN
# 251                                       0.0
# 468                                       NaN
# 471                                       NaN
# 523                                       NaN
# 528                                       NaN
# 547                                       NaN
# 655                                       NaN
# 676                                       NaN
# 683                                       0.6
# 687                                       NaN
# 752                                       NaN
# 806                                       NaN
# 826                                       NaN
# 830                                       NaN
#
#      Численность занятых (до 20 лет)  Численность занятых (от 20 до 29 лет)  \
# 26                               3.6                                   75.9
# 30                               7.4                                   75.6
# 35                               0.0                                   18.8
# 38                               5.3                                   29.6
# 40                               NaN                                    NaN
# 49                               6.6                                   78.9
# 126                              NaN                                    9.8
# 131                              NaN                                    NaN
# 251                              1.4                                   23.8
# 468                              2.6                                   82.6
# 471                              2.4                                  106.2
# 523                              0.7                                   66.9
# 528                              0.7                                   23.7
# 547                              0.2                                    6.8
# 655                              1.2                                   71.8
# 676                              0.6                                   38.2
# 683                              0.6                                   38.4
# 687                              6.7                                   86.4
# 752                              1.3                                   82.8
# 806                              0.7                                   45.1
# 826                              5.7                                   80.9
# 830                              0.0                                    3.8
#
#      Численность занятых (от 30 до 39 лет)  \
# 26                                   117.9
# 30                                    88.0
# 35                                    43.2
# 38                                    38.7
# 40                                     NaN
# 49                                   109.5
# 126                                   29.3
# 131                                    NaN
# 251                                   22.8
# 468                                   93.5
# 471                                  127.5
# 523                                   94.4
# 528                                   30.1
# 547                                    8.1
# 655                                   90.3
# 676                                   53.3
# 683                                   55.9
# 687                                   96.5
# 752                                  130.7
# 806                                  101.5
# 826                                  112.4
# 830                                    8.5
#
#      Численность занятых (от 40 до 49 лет)  \
# 26                                   117.9
# 30                                   102.8
# 35                                    25.9
# 38                                    45.6
# 40                                     NaN
# 49                                   128.8
# 126                                   24.6
# 131                                    NaN
# 251                                   23.9
# 468                                   89.5
# 471                                  129.1
# 523                                   85.3
# 528                                   26.7
# 547                                    7.8
# 655                                   86.4
# 676                                   47.7
# 683                                   46.5
# 687                                   88.4
# 752                                  123.3
# 806                                   89.3
# 826                                   97.3
# 830                                    7.9
#
#      Численность занятых (от 50 до 59 лет)  \
# 26                                    67.8
# 30                                    48.4
# 35                                     4.7
# 38                                    19.6
# 40                                     NaN
# 49                                    51.1
# 126                                    9.7
# 131                                    NaN
# 251                                   16.1
# 468                                   84.4
# 471                                  123.2
# 523                                   62.8
# 528                                   14.6
# 547                                    7.2
# 655                                   79.6
# 676                                   38.1
# 683                                   38.4
# 687                                   83.5
# 752                                  115.8
# 806                                   66.9
# 826                                   69.7
# 830                                    7.1
#
#      Численность занятых (60 и более лет)   Год
# 26                                   21.0  2001
# 30                                   14.1  2001
# 35                                    2.2  2001
# 38                                   11.6  2001
# 40                                    NaN  2001
# 49                                   12.4  2001
# 126                                   1.5  2004
# 131                                   NaN  2004
# 251                                   1.3  2007
# 468                                  18.6  2013
# 471                                  20.1  2013
# 523                                   4.4  2013
# 528                                   2.6  2013
# 547                                   1.9  2013
# 655                                  24.5  2017
# 676                                   4.7  2017
# 683                                  13.1  2017
# 687                                  26.4  2017
# 752                                  26.1  2019
# 806                                   6.0  2019
# 826                                  19.7  2019
# 830                                   2.6  2019

# %% [markdown]
# Действительно строка 40 и строка 131 с пустыми значениями. Предположительно по этим территориям не фиксировались данные, поэтому мы исключим строки.

# %%
 #удаляем строки, в которых отсутствуют данные по всем ячейкам. Это строки 40 и 131
data.drop(labels = [40,131],axis = 0, inplace = True)

# %%
# проверяем, как удалились строки 40 и 131
data[pd.isnull(data).any(axis=1)]
# Out:
#                           Территория  Численность населения  \
# 26           Калининградская область                  446.3
# 30                 Псковская область                  374.6
# 35              Республика Ингушетия                  145.4
# 38   Карачаево-Черкесская Республика                  184.8
# 49               Республика Мордовия                  432.1
# 126             Республика Ингушетия                  139.6
# 251                 Республика Алтай                   98.4
# 468                Орловская область                  394.1
# 471               Тамбовская область                  533.2
# 523  Ямало-Ненецкий автономный округ                  324.8
# 528                  Республика Тыва                  122.0
# 547       Чукотский автономный округ                   33.2
# 655                Орловская область                  378.5
# 676                Республика Адыгея                  200.1
# 683                   г. Севастополь                  202.0
# 687  Кабардино-Балкарская Республика                  433.2
# 752               Тамбовская область                  499.5
# 806  Ямало-Ненецкий автономный округ                  315.5
# 826                 Амурская область                  407.8
# 830       Чукотский автономный округ                   31.1
#
#      Занятые в экономике  Безработные  Уровень экономической активности  \
# 26                 403.6         42.8                              60.2
# 30                 335.9         38.7                              61.8
# 35                  94.7         50.8                              54.9
# 38                 150.5         34.3                              58.8
# 49                 386.9         45.2                              61.9
# 126                 74.9         64.7                              45.6
# 251                 89.5          8.9                              66.9
# 468                371.1         23.0                              65.6
# 471                508.6         24.6                              63.7
# 523                314.5         10.3                              77.0
# 528                 98.5         23.5                              57.7
# 547                 32.1          1.1                              83.1
# 655                353.9         24.6                              65.9
# 676                182.5         17.6                              60.2
# 683                192.8          9.2                              63.8
# 687                387.9         45.3                              68.3
# 752                479.9         19.6                              56.3
# 806                309.4          6.1                              75.9
# 826                385.9         21.9                              63.3
# 830                 30.0          1.2                              80.5
#
#      Уровень занятости  Уровень безработицы  \
# 26                54.5                  9.6
# 30                55.5                 10.3
# 35                35.8                 34.9
# 38                47.9                 18.6
# 49                55.4                 10.5
# 126               24.5                 46.3
# 251               61.0                  8.8
# 468               61.8                  5.8
# 471               60.8                  4.6
# 523               74.6                  3.2
# 528               46.6                 19.3
# 547               80.4                  3.3
# 655               61.7                  6.5
# 676               54.9                  8.8
# 683               60.9                  4.6
# 687               61.2                 10.5
# 752               54.1                  3.9
# 806               74.4                  1.9
# 826               59.9                  5.4
# 830               77.4                  3.8
#
#      Распределение безработных (до 20 лет)  \
# 26                                     5.5
# 30                                     6.0
# 35                                     0.7
# 38                                     2.1
# 49                                     2.7
# 126                                    5.3
# 251                                    NaN
# 468                                    2.4
# 471                                    2.3
# 523                                    6.2
# 528                                    2.6
# 547                                    5.0
# 655                                    2.7
# 676                                    1.1
# 683                                    NaN
# 687                                    1.8
# 752                                    1.6
# 806                                    2.3
# 826                                    0.8
# 830                                    1.3
#
#      Распределение безработных (от 20 до 29 лет)  \
# 26                                          34.0
# 30                                          26.9
# 35                                          38.0
# 38                                          36.9
# 49                                          36.8
# 126                                         44.6
# 251                                         40.6
# 468                                         31.1
# 471                                         29.1
# 523                                         54.4
# 528                                         44.2
# 547                                         36.9
# 655                                         34.8
# 676                                         26.8
# 683                                         32.9
# 687                                         39.0
# 752                                         25.9
# 806                                         52.2
# 826                                         35.9
# 830                                         49.0
#
#      Распределение безработных (от 30 до 39 лет)  \
# 26                                          18.9
# 30                                          25.6
# 35                                          24.1
# 38                                          36.2
# 49                                          30.3
# 126                                         28.7
# 251                                         19.4
# 468                                         24.3
# 471                                         23.7
# 523                                         17.1
# 528                                         29.3
# 547                                         26.9
# 655                                         29.2
# 676                                         31.6
# 683                                         22.2
# 687                                         29.9
# 752                                         32.4
# 806                                         24.6
# 826                                         29.2
# 830                                         32.2
#
#      Распределение безработных (от 40 до 49 лет)  \
# 26                                          25.1
# 30                                          32.3
# 35                                          33.0
# 38                                          16.8
# 49                                          21.9
# 126                                         16.7
# 251                                         30.4
# 468                                         26.8
# 471                                         25.5
# 523                                          8.6
# 528                                         19.0
# 547                                         21.7
# 655                                         18.7
# 676                                         25.7
# 683                                         18.2
# 687                                         17.3
# 752                                         21.7
# 806                                          5.9
# 826                                         18.9
# 830                                         12.7
#
#      Распределение безработных (от 50 до 59 лет)  \
# 26                                          16.5
# 30                                           9.3
# 35                                           3.8
# 38                                           8.0
# 49                                           8.3
# 126                                          4.5
# 251                                          9.7
# 468                                         15.4
# 471                                         19.3
# 523                                         13.8
# 528                                          4.7
# 547                                          5.8
# 655                                         14.7
# 676                                         14.8
# 683                                         20.3
# 687                                         12.1
# 752                                         18.4
# 806                                         15.0
# 826                                         14.9
# 830                                          4.8
#
#      Распределение безработных (60 и более лет)  \
# 26                                          NaN
# 30                                          NaN
# 35                                          0.4
# 38                                          NaN
# 49                                          NaN
# 126                                         0.2
# 251                                         NaN
# 468                                         NaN
# 471                                         NaN
# 523                                         NaN
# 528                                         0.2
# 547                                         3.7
# 655                                         NaN
# 676                                         NaN
# 683                                         6.4
# 687                                         NaN
# 752                                         NaN
# 806                                         NaN
# 826                                         0.2
# 830                                         NaN
#
#      Распределение занятых (до 20 лет)  \
# 26                                 0.9
# 30                                 2.2
# 35                                 NaN
# 38                                 3.5
# 49                                 1.7
# 126                                NaN
# 251                                1.6
# 468                                0.7
# 471                                0.5
# 523                                0.2
# 528                                0.7
# 547                                0.7
# 655                                0.3
# 676                                0.3
# 683                                0.3
# 687                                1.7
# 752                                0.3
# 806                                0.2
# 826                                1.5
# 830                                0.1
#
#      Распределение занятых (от 20 до 29 лет)  \
# 26                                      18.8
# 30                                      22.5
# 35                                      19.8
# 38                                      19.7
# 49                                      20.4
# 126                                     13.1
# 251                                     26.6
# 468                                     22.3
# 471                                     20.9
# 523                                     21.3
# 528                                     24.1
# 547                                     21.1
# 655                                     20.3
# 676                                     20.9
# 683                                     19.9
# 687                                     22.3
# 752                                     17.3
# 806                                     14.6
# 826                                     21.0
# 830                                     12.7
#
#      Распределение занятых (от 30 до 39 лет)  \
# 26                                      29.2
# 30                                      26.2
# 35                                      45.6
# 38                                      25.7
# 49                                      28.3
# 126                                     39.1
# 251                                     25.5
# 468                                     25.2
# 471                                     25.1
# 523                                     30.0
# 528                                     30.6
# 547                                     25.4
# 655                                     25.5
# 676                                     29.2
# 683                                     29.0
# 687                                     24.9
# 752                                     27.2
# 806                                     32.8
# 826                                     29.1
# 830                                     28.3
#
#      Распределение занятых (от 40 до 49 лет)  \
# 26                                      29.2
# 30                                      30.6
# 35                                      27.4
# 38                                      30.3
# 49                                      33.3
# 126                                     32.8
# 251                                     26.7
# 468                                     24.1
# 471                                     25.4
# 523                                     27.1
# 528                                     27.1
# 547                                     24.4
# 655                                     24.4
# 676                                     26.1
# 683                                     24.1
# 687                                     22.8
# 752                                     25.7
# 806                                     28.8
# 826                                     25.2
# 830                                     26.4
#
#      Распределение занятых (от 50 до 59 лет)  \
# 26                                      16.8
# 30                                      14.4
# 35                                       5.0
# 38                                      13.0
# 49                                      13.2
# 126                                     13.0
# 251                                     18.0
# 468                                     22.7
# 471                                     24.2
# 523                                     20.0
# 528                                     14.8
# 547                                     22.5
# 655                                     22.5
# 676                                     20.8
# 683                                     19.9
# 687                                     21.5
# 752                                     24.1
# 806                                     21.6
# 826                                     18.1
# 830                                     23.8
#
#      Распределение занятых (60 и более лет)  \
# 26                                      5.2
# 30                                      4.2
# 35                                      2.3
# 38                                      7.7
# 49                                      3.2
# 126                                     2.0
# 251                                     1.5
# 468                                     5.0
# 471                                     4.0
# 523                                     1.4
# 528                                     2.7
# 547                                     5.9
# 655                                     6.9
# 676                                     2.6
# 683                                     6.8
# 687                                     6.8
# 752                                     5.4
# 806                                     1.9
# 826                                     5.1
# 830                                     8.7
#
#      Численность безработных (до 20 лет)  \
# 26                                   2.4
# 30                                   2.3
# 35                                   0.4
# 38                                   0.7
# 49                                   1.2
# 126                                  3.4
# 251                                  0.0
# 468                                  0.6
# 471                                  0.6
# 523                                  0.6
# 528                                  0.6
# 547                                  0.1
# 655                                  0.7
# 676                                  0.2
# 683                                  NaN
# 687                                  0.8
# 752                                  0.3
# 806                                  0.1
# 826                                  0.2
# 830                                  0.0
#
#      Численность безработных (от 20 до 29 лет)  \
# 26                                        14.6
# 30                                        10.4
# 35                                        19.3
# 38                                        12.7
# 49                                        16.6
# 126                                       28.9
# 251                                        3.6
# 468                                        7.1
# 471                                        7.2
# 523                                        5.6
# 528                                       10.4
# 547                                        0.4
# 655                                        8.5
# 676                                        4.7
# 683                                        3.0
# 687                                       17.7
# 752                                        5.1
# 806                                        3.2
# 826                                        7.9
# 830                                        0.6
#
#      Численность безработных (от 30 до 39 лет)  \
# 26                                         8.1
# 30                                         9.9
# 35                                        12.2
# 38                                        12.4
# 49                                        13.7
# 126                                       18.6
# 251                                        1.7
# 468                                        5.6
# 471                                        5.8
# 523                                        1.8
# 528                                        6.9
# 547                                        0.3
# 655                                        7.2
# 676                                        5.5
# 683                                        2.0
# 687                                       13.6
# 752                                        6.4
# 806                                        1.5
# 826                                        6.4
# 830                                        0.4
#
#      Численность безработных (от 40 до 49 лет)  \
# 26                                        10.7
# 30                                        12.5
# 35                                        16.8
# 38                                         5.8
# 49                                         9.9
# 126                                       10.8
# 251                                        2.7
# 468                                        6.2
# 471                                        6.3
# 523                                        0.9
# 528                                        4.5
# 547                                        0.2
# 655                                        4.6
# 676                                        4.5
# 683                                        1.7
# 687                                        7.8
# 752                                        4.2
# 806                                        0.4
# 826                                        4.1
# 830                                        0.1
#
#      Численность безработных (от 50 до 59 лет)  \
# 26                                         7.1
# 30                                         3.6
# 35                                         1.9
# 38                                         2.7
# 49                                         3.8
# 126                                        2.9
# 251                                        0.9
# 468                                        3.5
# 471                                        4.8
# 523                                        1.4
# 528                                        1.1
# 547                                        0.1
# 655                                        3.6
# 676                                        2.6
# 683                                        1.9
# 687                                        5.5
# 752                                        3.6
# 806                                        0.9
# 826                                        3.3
# 830                                        0.1
#
#      Численность безработных (60 и более лет)  \
# 26                                        0.0
# 30                                        0.0
# 35                                        0.2
# 38                                        0.0
# 49                                        0.0
# 126                                       0.1
# 251                                       0.0
# 468                                       NaN
# 471                                       NaN
# 523                                       NaN
# 528                                       NaN
# 547                                       NaN
# 655                                       NaN
# 676                                       NaN
# 683                                       0.6
# 687                                       NaN
# 752                                       NaN
# 806                                       NaN
# 826                                       NaN
# 830                                       NaN
#
#      Численность занятых (до 20 лет)  Численность занятых (от 20 до 29 лет)  \
# 26                               3.6                                   75.9
# 30                               7.4                                   75.6
# 35                               0.0                                   18.8
# 38                               5.3                                   29.6
# 49                               6.6                                   78.9
# 126                              NaN                                    9.8
# 251                              1.4                                   23.8
# 468                              2.6                                   82.6
# 471                              2.4                                  106.2
# 523                              0.7                                   66.9
# 528                              0.7                                   23.7
# 547                              0.2                                    6.8
# 655                              1.2                                   71.8
# 676                              0.6                                   38.2
# 683                              0.6                                   38.4
# 687                              6.7                                   86.4
# 752                              1.3                                   82.8
# 806                              0.7                                   45.1
# 826                              5.7                                   80.9
# 830                              0.0                                    3.8
#
#      Численность занятых (от 30 до 39 лет)  \
# 26                                   117.9
# 30                                    88.0
# 35                                    43.2
# 38                                    38.7
# 49                                   109.5
# 126                                   29.3
# 251                                   22.8
# 468                                   93.5
# 471                                  127.5
# 523                                   94.4
# 528                                   30.1
# 547                                    8.1
# 655                                   90.3
# 676                                   53.3
# 683                                   55.9
# 687                                   96.5
# 752                                  130.7
# 806                                  101.5
# 826                                  112.4
# 830                                    8.5
#
#      Численность занятых (от 40 до 49 лет)  \
# 26                                   117.9
# 30                                   102.8
# 35                                    25.9
# 38                                    45.6
# 49                                   128.8
# 126                                   24.6
# 251                                   23.9
# 468                                   89.5
# 471                                  129.1
# 523                                   85.3
# 528                                   26.7
# 547                                    7.8
# 655                                   86.4
# 676                                   47.7
# 683                                   46.5
# 687                                   88.4
# 752                                  123.3
# 806                                   89.3
# 826                                   97.3
# 830                                    7.9
#
#      Численность занятых (от 50 до 59 лет)  \
# 26                                    67.8
# 30                                    48.4
# 35                                     4.7
# 38                                    19.6
# 49                                    51.1
# 126                                    9.7
# 251                                   16.1
# 468                                   84.4
# 471                                  123.2
# 523                                   62.8
# 528                                   14.6
# 547                                    7.2
# 655                                   79.6
# 676                                   38.1
# 683                                   38.4
# 687                                   83.5
# 752                                  115.8
# 806                                   66.9
# 826                                   69.7
# 830                                    7.1
#
#      Численность занятых (60 и более лет)   Год
# 26                                   21.0  2001
# 30                                   14.1  2001
# 35                                    2.2  2001
# 38                                   11.6  2001
# 49                                   12.4  2001
# 126                                   1.5  2004
# 251                                   1.3  2007
# 468                                  18.6  2013
# 471                                  20.1  2013
# 523                                   4.4  2013
# 528                                   2.6  2013
# 547                                   1.9  2013
# 655                                  24.5  2017
# 676                                   4.7  2017
# 683                                  13.1  2017
# 687                                  26.4  2017
# 752                                  26.1  2019
# 806                                   6.0  2019
# 826                                  19.7  2019
# 830                                   2.6  2019

# %% [markdown]
# Проверим сколько пропусков у нас осталось сейчас.

# %%
data.isnull().sum()
# Out:
# Территория                                      0
# Численность населения                           0
# Занятые в экономике                             0
# Безработные                                     0
# Уровень экономической активности                0
# Уровень занятости                               0
# Уровень безработицы                             0
# Распределение безработных (до 20 лет)           2
# Распределение безработных (от 20 до 29 лет)     0
# Распределение безработных (от 30 до 39 лет)     0
# Распределение безработных (от 40 до 49 лет)     0
# Распределение безработных (от 50 до 59 лет)     0
# Распределение безработных (60 и более лет)     14
# Распределение занятых (до 20 лет)               2
# Распределение занятых (от 20 до 29 лет)         0
# Распределение занятых (от 30 до 39 лет)         0
# Распределение занятых (от 40 до 49 лет)         0
# Распределение занятых (от 50 до 59 лет)         0
# Распределение занятых (60 и более лет)          0
# Численность безработных (до 20 лет)             1
# Численность безработных (от 20 до 29 лет)       0
# Численность безработных (от 30 до 39 лет)       0
# Численность безработных (от 40 до 49 лет)       0
# Численность безработных (от 50 до 59 лет)       0
# Численность безработных (60 и более лет)       12
# Численность занятых (до 20 лет)                 1
# Численность занятых (от 20 до 29 лет)           0
# Численность занятых (от 30 до 39 лет)           0
# Численность занятых (от 40 до 49 лет)           0
# Численность занятых (от 50 до 59 лет)           0
# Численность занятых (60 и более лет)            0
# Год                                             0
# dtype: int64

# %% [markdown]
# Осталось еще несколько столбцов с пропусками - поработаем и с ними.
# Значения в этих ячейках указаны в процентах. Посчитаем сколько процентов сейчас, учитывая, что у нас есть незаполненные ячейки. В указанных столбцах распределение безработных и занятых.

# %%
# выведем индексы, они нам понадобятся в дальнейшей работе
data_index = data[pd.isnull(data).any(axis=1)]
print(data_index.index)
# Out:
# Int64Index([ 26,  30,  35,  38,  49, 126, 251, 468, 471, 523, 528, 547, 655,
#             676, 683, 687, 752, 806, 826, 830],
#            dtype='int64')

# %%
# создадим функцию для расчета значений по нескольким столбцам
def data_dis_unage_emage (index):
    data_dis_unage = data.loc[index, ['Распределение безработных (до 20 лет)', 'Распределение безработных (от 20 до 29 лет)',
                                      'Распределение безработных (от 30 до 39 лет)', 'Распределение безработных (от 40 до 49 лет)',
                                      'Распределение безработных (от 50 до 59 лет)', 'Распределение безработных (60 и более лет)']].sum()
    data_dis_emage = data.loc[index, ['Распределение занятых (до 20 лет)', 'Распределение занятых (от 20 до 29 лет)',
                                      'Распределение занятых (от 30 до 39 лет)', 'Распределение занятых (от 40 до 49 лет)',
                                      'Распределение занятых (от 50 до 59 лет)', 'Распределение занятых (60 и более лет)']].sum()

    # выведем значение столбца с наименованием территорий
    name = data.loc[index, 'Территория']

    print(name)
    print('Распределение безработных -', data_dis_unage.round(), '%')
    print('Распределение занятых -', data_dis_emage.round(), '%')
    print()

# пройдемся циклом по всем нашим строкам со значением NaN в рассматриваемых столбцах
for i in data_index.index:
    data_dis_unage_emage(i)
# Out:
# Калининградская область
# Распределение безработных - 100.0 %
# Распределение занятых - 100.0 %
#
# Псковская область
# Распределение безработных - 100.0 %
# Распределение занятых - 100.0 %
#
# Республика Ингушетия
# Распределение безработных - 100.0 %
# Распределение занятых - 100.0 %
#
# Карачаево-Черкесская Республика
# Распределение безработных - 100.0 %
# Распределение занятых - 100.0 %
#
# Республика Мордовия
# Распределение безработных - 100.0 %
# Распределение занятых - 100.0 %
#
# Республика Ингушетия
# Распределение безработных - 100.0 %
# Распределение занятых - 100.0 %
#
# Республика Алтай
# Распределение безработных - 100.0 %
# Распределение занятых - 100.0 %
#
# Орловская область
# Распределение безработных - 100.0 %
# Распределение занятых - 100.0 %
#
# Тамбовская область
# Распределение безработных - 100.0 %
# Распределение занятых - 100.0 %
#
# Ямало-Ненецкий автономный округ
# Распределение безработных - 100.0 %
# Распределение занятых - 100.0 %
#
# Республика Тыва
# Распределение безработных - 100.0 %
# Распределение занятых - 100.0 %
#
# Чукотский автономный округ
# Распределение безработных - 100.0 %
# Распределение занятых - 100.0 %
#
# Орловская область
# Распределение безработных - 100.0 %
# Распределение занятых - 100.0 %
#
# Республика Адыгея
# Распределение безработных - 100.0 %
# Распределение занятых - 100.0 %
#
# г. Севастополь
# Распределение безработных - 100.0 %
# Распределение занятых - 100.0 %
#
# Кабардино-Балкарская Республика
# Распределение безработных - 100.0 %
# Распределение занятых - 100.0 %
#
# Тамбовская область
# Распределение безработных - 100.0 %
# Распределение занятых - 100.0 %
#
# Ямало-Ненецкий автономный округ
# Распределение безработных - 100.0 %
# Распределение занятых - 100.0 %
#
# Амурская область
# Распределение безработных - 100.0 %
# Распределение занятых - 100.0 %
#
# Чукотский автономный округ
# Распределение безработных - 100.0 %
# Распределение занятых - 100.0 %

# %% [markdown]
# Мы проверили распределение занятых и безработных людей, и учитывая что некоторые ячейки у нас имели значение NaN, то все равно общий процент 100%. Тем самым мы можем заменить NaN на значение 0 в этих ячейках.

# %%
# заменяем с помощью метода fillna()
data[['Распределение безработных (до 20 лет)', 'Распределение безработных (от 20 до 29 лет)',  'Распределение безработных (от 30 до 39 лет)', 'Распределение безработных (от 40 до 49 лет)', 'Распределение безработных (от 50 до 59 лет)', 'Распределение безработных (60 и более лет)']] = data[['Распределение безработных (до 20 лет)', 'Распределение безработных (от 20 до 29 лет)', 'Распределение безработных (от 30 до 39 лет)', 'Распределение безработных (от 40 до 49 лет)', 'Распределение безработных (от 50 до 59 лет)', 'Распределение безработных (60 и более лет)']].fillna(0)
data[['Распределение занятых (до 20 лет)', 'Распределение занятых (от 20 до 29 лет)', 'Распределение занятых (от 30 до 39 лет)', 'Распределение занятых (от 40 до 49 лет)',  'Распределение занятых (от 50 до 59 лет)', 'Распределение занятых (60 и более лет)']] = data[['Распределение занятых (до 20 лет)', 'Распределение занятых (от 20 до 29 лет)','Распределение занятых (от 30 до 39 лет)', 'Распределение занятых (от 40 до 49 лет)',  'Распределение занятых (от 50 до 59 лет)', 'Распределение занятых (60 и более лет)']].fillna(0)

# делаем проверку по индексу 26
data.loc[26]
# Out:
# Территория                                     Калининградская область
# Численность населения                                            446.3
# Занятые в экономике                                              403.6
# Безработные                                                       42.8
# Уровень экономической активности                                  60.2
# Уровень занятости                                                 54.5
# Уровень безработицы                                                9.6
# Распределение безработных (до 20 лет)                              5.5
# Распределение безработных (от 20 до 29 лет)                       34.0
# Распределение безработных (от 30 до 39 лет)                       18.9
# Распределение безработных (от 40 до 49 лет)                       25.1
# Распределение безработных (от 50 до 59 лет)                       16.5
# Распределение безработных (60 и более лет)                         0.0
# Распределение занятых (до 20 лет)                                  0.9
# Распределение занятых (от 20 до 29 лет)                           18.8
# Распределение занятых (от 30 до 39 лет)                           29.2
# Распределение занятых (от 40 до 49 лет)                           29.2
# Распределение занятых (от 50 до 59 лет)                           16.8
# Распределение занятых (60 и более лет)                             5.2
# Численность безработных (до 20 лет)                                2.4
# Численность безработных (от 20 до 29 лет)                         14.6
# Численность безработных (от 30 до 39 лет)                          8.1
# Численность безработных (от 40 до 49 лет)                         10.7
# Численность безработных (от 50 до 59 лет)                          7.1
# Численность безработных (60 и более лет)                           0.0
# Численность занятых (до 20 лет)                                    3.6
# Численность занятых (от 20 до 29 лет)                             75.9
# Численность занятых (от 30 до 39 лет)                            117.9
# Численность занятых (от 40 до 49 лет)                            117.9
# Численность занятых (от 50 до 59 лет)                             67.8
# Численность занятых (60 и более лет)                              21.0
# Год                                                               2001
# Name: 26, dtype: object

# %% [markdown]
# В столбце "Распределение безработных (60 и более лет)" значение с "NaN" поменялось на 0.0, значения изменились. Продолжим работать с остальными пропусками.

# %%
# проверяем какие пропуска остались
data[pd.isnull(data).any(axis=1)]
# Out:
#                           Территория  Численность населения  \
# 126             Республика Ингушетия                  139.6
# 468                Орловская область                  394.1
# 471               Тамбовская область                  533.2
# 523  Ямало-Ненецкий автономный округ                  324.8
# 528                  Республика Тыва                  122.0
# 547       Чукотский автономный округ                   33.2
# 655                Орловская область                  378.5
# 676                Республика Адыгея                  200.1
# 683                   г. Севастополь                  202.0
# 687  Кабардино-Балкарская Республика                  433.2
# 752               Тамбовская область                  499.5
# 806  Ямало-Ненецкий автономный округ                  315.5
# 826                 Амурская область                  407.8
# 830       Чукотский автономный округ                   31.1
#
#      Занятые в экономике  Безработные  Уровень экономической активности  \
# 126                 74.9         64.7                              45.6
# 468                371.1         23.0                              65.6
# 471                508.6         24.6                              63.7
# 523                314.5         10.3                              77.0
# 528                 98.5         23.5                              57.7
# 547                 32.1          1.1                              83.1
# 655                353.9         24.6                              65.9
# 676                182.5         17.6                              60.2
# 683                192.8          9.2                              63.8
# 687                387.9         45.3                              68.3
# 752                479.9         19.6                              56.3
# 806                309.4          6.1                              75.9
# 826                385.9         21.9                              63.3
# 830                 30.0          1.2                              80.5
#
#      Уровень занятости  Уровень безработицы  \
# 126               24.5                 46.3
# 468               61.8                  5.8
# 471               60.8                  4.6
# 523               74.6                  3.2
# 528               46.6                 19.3
# 547               80.4                  3.3
# 655               61.7                  6.5
# 676               54.9                  8.8
# 683               60.9                  4.6
# 687               61.2                 10.5
# 752               54.1                  3.9
# 806               74.4                  1.9
# 826               59.9                  5.4
# 830               77.4                  3.8
#
#      Распределение безработных (до 20 лет)  \
# 126                                    5.3
# 468                                    2.4
# 471                                    2.3
# 523                                    6.2
# 528                                    2.6
# 547                                    5.0
# 655                                    2.7
# 676                                    1.1
# 683                                    0.0
# 687                                    1.8
# 752                                    1.6
# 806                                    2.3
# 826                                    0.8
# 830                                    1.3
#
#      Распределение безработных (от 20 до 29 лет)  \
# 126                                         44.6
# 468                                         31.1
# 471                                         29.1
# 523                                         54.4
# 528                                         44.2
# 547                                         36.9
# 655                                         34.8
# 676                                         26.8
# 683                                         32.9
# 687                                         39.0
# 752                                         25.9
# 806                                         52.2
# 826                                         35.9
# 830                                         49.0
#
#      Распределение безработных (от 30 до 39 лет)  \
# 126                                         28.7
# 468                                         24.3
# 471                                         23.7
# 523                                         17.1
# 528                                         29.3
# 547                                         26.9
# 655                                         29.2
# 676                                         31.6
# 683                                         22.2
# 687                                         29.9
# 752                                         32.4
# 806                                         24.6
# 826                                         29.2
# 830                                         32.2
#
#      Распределение безработных (от 40 до 49 лет)  \
# 126                                         16.7
# 468                                         26.8
# 471                                         25.5
# 523                                          8.6
# 528                                         19.0
# 547                                         21.7
# 655                                         18.7
# 676                                         25.7
# 683                                         18.2
# 687                                         17.3
# 752                                         21.7
# 806                                          5.9
# 826                                         18.9
# 830                                         12.7
#
#      Распределение безработных (от 50 до 59 лет)  \
# 126                                          4.5
# 468                                         15.4
# 471                                         19.3
# 523                                         13.8
# 528                                          4.7
# 547                                          5.8
# 655                                         14.7
# 676                                         14.8
# 683                                         20.3
# 687                                         12.1
# 752                                         18.4
# 806                                         15.0
# 826                                         14.9
# 830                                          4.8
#
#      Распределение безработных (60 и более лет)  \
# 126                                         0.2
# 468                                         0.0
# 471                                         0.0
# 523                                         0.0
# 528                                         0.2
# 547                                         3.7
# 655                                         0.0
# 676                                         0.0
# 683                                         6.4
# 687                                         0.0
# 752                                         0.0
# 806                                         0.0
# 826                                         0.2
# 830                                         0.0
#
#      Распределение занятых (до 20 лет)  \
# 126                                0.0
# 468                                0.7
# 471                                0.5
# 523                                0.2
# 528                                0.7
# 547                                0.7
# 655                                0.3
# 676                                0.3
# 683                                0.3
# 687                                1.7
# 752                                0.3
# 806                                0.2
# 826                                1.5
# 830                                0.1
#
#      Распределение занятых (от 20 до 29 лет)  \
# 126                                     13.1
# 468                                     22.3
# 471                                     20.9
# 523                                     21.3
# 528                                     24.1
# 547                                     21.1
# 655                                     20.3
# 676                                     20.9
# 683                                     19.9
# 687                                     22.3
# 752                                     17.3
# 806                                     14.6
# 826                                     21.0
# 830                                     12.7
#
#      Распределение занятых (от 30 до 39 лет)  \
# 126                                     39.1
# 468                                     25.2
# 471                                     25.1
# 523                                     30.0
# 528                                     30.6
# 547                                     25.4
# 655                                     25.5
# 676                                     29.2
# 683                                     29.0
# 687                                     24.9
# 752                                     27.2
# 806                                     32.8
# 826                                     29.1
# 830                                     28.3
#
#      Распределение занятых (от 40 до 49 лет)  \
# 126                                     32.8
# 468                                     24.1
# 471                                     25.4
# 523                                     27.1
# 528                                     27.1
# 547                                     24.4
# 655                                     24.4
# 676                                     26.1
# 683                                     24.1
# 687                                     22.8
# 752                                     25.7
# 806                                     28.8
# 826                                     25.2
# 830                                     26.4
#
#      Распределение занятых (от 50 до 59 лет)  \
# 126                                     13.0
# 468                                     22.7
# 471                                     24.2
# 523                                     20.0
# 528                                     14.8
# 547                                     22.5
# 655                                     22.5
# 676                                     20.8
# 683                                     19.9
# 687                                     21.5
# 752                                     24.1
# 806                                     21.6
# 826                                     18.1
# 830                                     23.8
#
#      Распределение занятых (60 и более лет)  \
# 126                                     2.0
# 468                                     5.0
# 471                                     4.0
# 523                                     1.4
# 528                                     2.7
# 547                                     5.9
# 655                                     6.9
# 676                                     2.6
# 683                                     6.8
# 687                                     6.8
# 752                                     5.4
# 806                                     1.9
# 826                                     5.1
# 830                                     8.7
#
#      Численность безработных (до 20 лет)  \
# 126                                  3.4
# 468                                  0.6
# 471                                  0.6
# 523                                  0.6
# 528                                  0.6
# 547                                  0.1
# 655                                  0.7
# 676                                  0.2
# 683                                  NaN
# 687                                  0.8
# 752                                  0.3
# 806                                  0.1
# 826                                  0.2
# 830                                  0.0
#
#      Численность безработных (от 20 до 29 лет)  \
# 126                                       28.9
# 468                                        7.1
# 471                                        7.2
# 523                                        5.6
# 528                                       10.4
# 547                                        0.4
# 655                                        8.5
# 676                                        4.7
# 683                                        3.0
# 687                                       17.7
# 752                                        5.1
# 806                                        3.2
# 826                                        7.9
# 830                                        0.6
#
#      Численность безработных (от 30 до 39 лет)  \
# 126                                       18.6
# 468                                        5.6
# 471                                        5.8
# 523                                        1.8
# 528                                        6.9
# 547                                        0.3
# 655                                        7.2
# 676                                        5.5
# 683                                        2.0
# 687                                       13.6
# 752                                        6.4
# 806                                        1.5
# 826                                        6.4
# 830                                        0.4
#
#      Численность безработных (от 40 до 49 лет)  \
# 126                                       10.8
# 468                                        6.2
# 471                                        6.3
# 523                                        0.9
# 528                                        4.5
# 547                                        0.2
# 655                                        4.6
# 676                                        4.5
# 683                                        1.7
# 687                                        7.8
# 752                                        4.2
# 806                                        0.4
# 826                                        4.1
# 830                                        0.1
#
#      Численность безработных (от 50 до 59 лет)  \
# 126                                        2.9
# 468                                        3.5
# 471                                        4.8
# 523                                        1.4
# 528                                        1.1
# 547                                        0.1
# 655                                        3.6
# 676                                        2.6
# 683                                        1.9
# 687                                        5.5
# 752                                        3.6
# 806                                        0.9
# 826                                        3.3
# 830                                        0.1
#
#      Численность безработных (60 и более лет)  \
# 126                                       0.1
# 468                                       NaN
# 471                                       NaN
# 523                                       NaN
# 528                                       NaN
# 547                                       NaN
# 655                                       NaN
# 676                                       NaN
# 683                                       0.6
# 687                                       NaN
# 752                                       NaN
# 806                                       NaN
# 826                                       NaN
# 830                                       NaN
#
#      Численность занятых (до 20 лет)  Численность занятых (от 20 до 29 лет)  \
# 126                              NaN                                    9.8
# 468                              2.6                                   82.6
# 471                              2.4                                  106.2
# 523                              0.7                                   66.9
# 528                              0.7                                   23.7
# 547                              0.2                                    6.8
# 655                              1.2                                   71.8
# 676                              0.6                                   38.2
# 683                              0.6                                   38.4
# 687                              6.7                                   86.4
# 752                              1.3                                   82.8
# 806                              0.7                                   45.1
# 826                              5.7                                   80.9
# 830                              0.0                                    3.8
#
#      Численность занятых (от 30 до 39 лет)  \
# 126                                   29.3
# 468                                   93.5
# 471                                  127.5
# 523                                   94.4
# 528                                   30.1
# 547                                    8.1
# 655                                   90.3
# 676                                   53.3
# 683                                   55.9
# 687                                   96.5
# 752                                  130.7
# 806                                  101.5
# 826                                  112.4
# 830                                    8.5
#
#      Численность занятых (от 40 до 49 лет)  \
# 126                                   24.6
# 468                                   89.5
# 471                                  129.1
# 523                                   85.3
# 528                                   26.7
# 547                                    7.8
# 655                                   86.4
# 676                                   47.7
# 683                                   46.5
# 687                                   88.4
# 752                                  123.3
# 806                                   89.3
# 826                                   97.3
# 830                                    7.9
#
#      Численность занятых (от 50 до 59 лет)  \
# 126                                    9.7
# 468                                   84.4
# 471                                  123.2
# 523                                   62.8
# 528                                   14.6
# 547                                    7.2
# 655                                   79.6
# 676                                   38.1
# 683                                   38.4
# 687                                   83.5
# 752                                  115.8
# 806                                   66.9
# 826                                   69.7
# 830                                    7.1
#
#      Численность занятых (60 и более лет)   Год
# 126                                   1.5  2004
# 468                                  18.6  2013
# 471                                  20.1  2013
# 523                                   4.4  2013
# 528                                   2.6  2013
# 547                                   1.9  2013
# 655                                  24.5  2017
# 676                                   4.7  2017
# 683                                  13.1  2017
# 687                                  26.4  2017
# 752                                  26.1  2019
# 806                                   6.0  2019
# 826                                  19.7  2019
# 830                                   2.6  2019

# %%
# выведем индексы, они нам понадобятся в дальнейшей работе
data_index_1 = data[pd.isnull(data).any(axis=1)]

# %%
# заменяем с помощью метода fillna()
data[['Численность безработных (до 20 лет)',
      'Численность безработных (от 20 до 29 лет)',
      'Численность безработных (от 30 до 39 лет)',
      'Численность безработных (от 40 до 49 лет)',
      'Численность безработных (от 50 до 59 лет)',
      'Численность безработных (60 и более лет)']] = data[['Численность безработных (до 20 лет)',
                                                             'Численность безработных (от 20 до 29 лет)',
                                                             'Численность безработных (от 30 до 39 лет)',
                                                             'Численность безработных (от 40 до 49 лет)',
                                                             'Численность безработных (от 50 до 59 лет)',
                                                             'Численность безработных (60 и более лет)']].fillna(0)
data[['Численность занятых (до 20 лет)',
      'Распределение занятых (от 20 до 29 лет)',
      'Распределение занятых (от 30 до 39 лет)',
      'Распределение занятых (от 40 до 49 лет)',
      'Распределение занятых (от 50 до 59 лет)',
      'Распределение занятых (60 и более лет)']] = data[['Распределение занятых (до 20 лет)',
                                                         'Распределение занятых (от 20 до 29 лет)',
                                                         'Распределение занятых (от 30 до 39 лет)',
                                                         'Распределение занятых (от 40 до 49 лет)',
                                                         'Распределение занятых (от 50 до 59 лет)',
                                                         'Распределение занятых (60 и более лет)']].fillna(0)

# %%
# делаем проверку по индексу 26
data.loc[683]
# Out:
# Территория                                     г. Севастополь
# Численность населения                                   202.0
# Занятые в экономике                                     192.8
# Безработные                                               9.2
# Уровень экономической активности                         63.8
# Уровень занятости                                        60.9
# Уровень безработицы                                       4.6
# Распределение безработных (до 20 лет)                     0.0
# Распределение безработных (от 20 до 29 лет)              32.9
# Распределение безработных (от 30 до 39 лет)              22.2
# Распределение безработных (от 40 до 49 лет)              18.2
# Распределение безработных (от 50 до 59 лет)              20.3
# Распределение безработных (60 и более лет)                6.4
# Распределение занятых (до 20 лет)                         0.3
# Распределение занятых (от 20 до 29 лет)                  19.9
# Распределение занятых (от 30 до 39 лет)                  29.0
# Распределение занятых (от 40 до 49 лет)                  24.1
# Распределение занятых (от 50 до 59 лет)                  19.9
# Распределение занятых (60 и более лет)                    6.8
# Численность безработных (до 20 лет)                       0.0
# Численность безработных (от 20 до 29 лет)                 3.0
# Численность безработных (от 30 до 39 лет)                 2.0
# Численность безработных (от 40 до 49 лет)                 1.7
# Численность безработных (от 50 до 59 лет)                 1.9
# Численность безработных (60 и более лет)                  0.6
# Численность занятых (до 20 лет)                           0.3
# Численность занятых (от 20 до 29 лет)                    38.4
# Численность занятых (от 30 до 39 лет)                    55.9
# Численность занятых (от 40 до 49 лет)                    46.5
# Численность занятых (от 50 до 59 лет)                    38.4
# Численность занятых (60 и более лет)                     13.1
# Год                                                      2017
# Name: 683, dtype: object

# %% [markdown]
# Пропуска заполнили, но чтобы быть точно уверенными, что все в порядке - давайте проверим сколько пропусков осталось.

# %%
# проверим сколько пропусков сейчас осталось
data.isnull().sum()
# Out:
# Территория                                     0
# Численность населения                          0
# Занятые в экономике                            0
# Безработные                                    0
# Уровень экономической активности               0
# Уровень занятости                              0
# Уровень безработицы                            0
# Распределение безработных (до 20 лет)          0
# Распределение безработных (от 20 до 29 лет)    0
# Распределение безработных (от 30 до 39 лет)    0
# Распределение безработных (от 40 до 49 лет)    0
# Распределение безработных (от 50 до 59 лет)    0
# Распределение безработных (60 и более лет)     0
# Распределение занятых (до 20 лет)              0
# Распределение занятых (от 20 до 29 лет)        0
# Распределение занятых (от 30 до 39 лет)        0
# Распределение занятых (от 40 до 49 лет)        0
# Распределение занятых (от 50 до 59 лет)        0
# Распределение занятых (60 и более лет)         0
# Численность безработных (до 20 лет)            0
# Численность безработных (от 20 до 29 лет)      0
# Численность безработных (от 30 до 39 лет)      0
# Численность безработных (от 40 до 49 лет)      0
# Численность безработных (от 50 до 59 лет)      0
# Численность безработных (60 и более лет)       0
# Численность занятых (до 20 лет)                0
# Численность занятых (от 20 до 29 лет)          0
# Численность занятых (от 30 до 39 лет)          0
# Численность занятых (от 40 до 49 лет)          0
# Численность занятых (от 50 до 59 лет)          0
# Численность занятых (60 и более лет)           0
# Год                                            0
# dtype: int64

# %% [markdown]
# Все пропуски обработаны. Теперь проверим дубликаты.

# %% [markdown]
# **Проверка и обработка дубликатов**

# %%
# проверим количество дубликатов (метод duplicated())
sum_duplicated = data.duplicated().sum()
print('Количество дубликатов: ', sum_duplicated)
# Out:
# Количество дубликатов:  0

# %% [markdown]
# Количество дубликатов: 0

# %% [markdown]
# **Проверка и обработка типов данных**
#
# Перед тем, как приступить к обработке типов данных столбцов - рассмотрим какие типы данных в данный момент.

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 829 entries, 0 to 830
# Data columns (total 32 columns):
#  #   Column                                       Non-Null Count  Dtype
# ---  ------                                       --------------  -----
#  0   Территория                                   829 non-null    object
#  1   Численность населения                        829 non-null    float64
#  2   Занятые в экономике                          829 non-null    float64
#  3   Безработные                                  829 non-null    float64
#  4   Уровень экономической активности             829 non-null    float64
#  5   Уровень занятости                            829 non-null    float64
#  6   Уровень безработицы                          829 non-null    float64
#  7   Распределение безработных (до 20 лет)        829 non-null    float64
#  8   Распределение безработных (от 20 до 29 лет)  829 non-null    float64
#  9   Распределение безработных (от 30 до 39 лет)  829 non-null    float64
#  10  Распределение безработных (от 40 до 49 лет)  829 non-null    float64
#  11  Распределение безработных (от 50 до 59 лет)  829 non-null    float64
#  12  Распределение безработных (60 и более лет)   829 non-null    float64
#  13  Распределение занятых (до 20 лет)            829 non-null    float64
#  14  Распределение занятых (от 20 до 29 лет)      829 non-null    float64
#  15  Распределение занятых (от 30 до 39 лет)      829 non-null    float64
#  16  Распределение занятых (от 40 до 49 лет)      829 non-null    float64
#  17  Распределение занятых (от 50 до 59 лет)      829 non-null    float64
#  18  Распределение занятых (60 и более лет)       829 non-null    float64
#  19  Численность безработных (до 20 лет)          829 non-null    float64
#  20  Численность безработных (от 20 до 29 лет)    829 non-null    float64
#  21  Численность безработных (от 30 до 39 лет)    829 non-null    float64
#  22  Численность безработных (от 40 до 49 лет)    829 non-null    float64
#  23  Численность безработных (от 50 до 59 лет)    829 non-null    float64
#  24  Численность безработных (60 и более лет)     829 non-null    float64
#  25  Численность занятых (до 20 лет)              829 non-null    float64
#  26  Численность занятых (от 20 до 29 лет)        829 non-null    float64
#  27  Численность занятых (от 30 до 39 лет)        829 non-null    float64
#  28  Численность занятых (от 40 до 49 лет)        829 non-null    float64
#  29  Численность занятых (от 50 до 59 лет)        829 non-null    float64
#  30  Численность занятых (60 и более лет)         829 non-null    float64
#  31  Год                                          829 non-null    int64
# dtypes: float64(30), int64(1), object(1)
# memory usage: 246.0+ KB

# %%
# изменением типы на int
data['Численность населения'] = data['Численность населения'].astype(int)
data['Занятые в экономике'] = data['Занятые в экономике'].astype(int)
data['Безработные'] = data['Безработные'].astype(int)

# %% [markdown]
# Посмотрим прошли ли изменения типов

# %%
data.dtypes
# Out:
# Территория                                      object
# Численность населения                            int64
# Занятые в экономике                              int64
# Безработные                                      int64
# Уровень экономической активности               float64
# Уровень занятости                              float64
# Уровень безработицы                            float64
# Распределение безработных (до 20 лет)          float64
# Распределение безработных (от 20 до 29 лет)    float64
# Распределение безработных (от 30 до 39 лет)    float64
# Распределение безработных (от 40 до 49 лет)    float64
# Распределение безработных (от 50 до 59 лет)    float64
# Распределение безработных (60 и более лет)     float64
# Распределение занятых (до 20 лет)              float64
# Распределение занятых (от 20 до 29 лет)        float64
# Распределение занятых (от 30 до 39 лет)        float64
# Распределение занятых (от 40 до 49 лет)        float64
# Распределение занятых (от 50 до 59 лет)        float64
# Распределение занятых (60 и более лет)         float64
# Численность безработных (до 20 лет)            float64
# Численность безработных (от 20 до 29 лет)      float64
# Численность безработных (от 30 до 39 лет)      float64
# Численность безработных (от 40 до 49 лет)      float64
# Численность безработных (от 50 до 59 лет)      float64
# Численность безработных (60 и более лет)       float64
# Численность занятых (до 20 лет)                float64
# Численность занятых (от 20 до 29 лет)          float64
# Численность занятых (от 30 до 39 лет)          float64
# Численность занятых (от 40 до 49 лет)          float64
# Численность занятых (от 50 до 59 лет)          float64
# Численность занятых (60 и более лет)           float64
# Год                                              int64
# dtype: object

# %% [markdown]
# Мы изменили только "Численность населения", "Занятые в экономике", "Безработные" на целочисленное значение. По остальным столбцам оставили дробное, т.к. указаны значения в процентном соотношении.

# %% [markdown]
# **Вывод**
#
# В предыдущих разделах мы изучили и подготовили наши данные для того, чтобы в дальнейшем можно было без трудностей проанализировать их.
# В следующем разделе мы будем исследовать данные и при необходимости построим различные гистограммы.

# %% [markdown]
# **Исследовательский анализ данных**

# %%
# изучаем зависимость занятых и безработных от года
#sns.pairplot(data, x_vars=['Занятые в экономике', 'Безработные'], y_vars=['Год'], size=6)
#plt.show()

# %% [markdown]
# **Построение гистограммы с количеством безработных и занятых (общему количеству и по конкретной территории)**
#
# Посчитаем общее количество безработных по территориям сначала в табличном варианте и выведем первые 10 строк.

# %%
sum_unemployed = data.groupby('Территория')['Безработные'].sum().sort_values(ascending=False)
print(sum_unemployed.head(10))
# Out:
# Территория
# Республика Северная Осетия - Алания    44141
# Российская Федерация                   43010
# Приволжский федеральный округ           8570
# Южный федеральный округ                 7503
# Центральный федеральный округ           6667
# Сибирский федеральный округ             6640
# Уральский федеральный округ             3711
# Северо-Западный федеральный округ       3455
# Северо-Кавказский федеральный округ     2680
# Дальневосточный федеральный округ       2360
# Name: Безработные, dtype: int64

# %% [markdown]
# Теперь построим гистограмму на основе полученной таблицы.

# %%
# Количество безработных на разных территориях

# построим гистограмму
sum_unemployed.plot(x = 'Территория', y = 'Безработные', kind = 'bar', figsize=(20,8), grid=True, title = 'Количество безработных на разных территориях')

# меняем наименование горизонтальной линии ('X')
plt.xlabel('Территория')
# меняем наименование вертикальной линии ('Y')
plt.ylabel('Безработные')
plt.show()

# %%
sum_unemployed.head(2)
# Out:
# Территория
# Республика Северная Осетия - Алания    44141
# Российская Федерация                   43010
# Name: Безработные, dtype: int64

# %% [markdown]
# Большая часть безработных, а именно на территориях Республики Северной Осетии - Алания и Российская Федерация.
# Предположительно Республики Северной Осетии - Алания нехватка рабочих мест, а в РФ это может быть обусловлено большим количеством субьектов.
# Так же давайте не забывать, что у нас подсчет по всем безработным по всем возрастам. И может быть такое, что некоторые люди не подходят к той или иной работе в силу возраста, а та работа, которая им необходима уже переполнена персоналом.

# %%
sum_unemployed.tail(2)
# Out:
# Территория
# Чукотский автономный округ    10
# Ненецкий автономный округ     10
# Name: Безработные, dtype: int64

# %% [markdown]
# Минимальное количество может говорить о том, что большиству жителей этих регионов находится свое место в трудовых резервах.

# %% [markdown]
# Посчитаем общее количество занятых по территориям.

# %%
sum_employed = data.groupby('Территория')['Занятые в экономике'].sum().sort_values(ascending=False)
print(sum_employed.head(10))
# Out:
# Территория
# Российская Федерация                 630862
# Центральный федеральный округ        156268
# Приволжский федеральный округ        131433
# Южный федеральный округ               72113
# Сибирский федеральный округ           71515
# Северо-Западный федеральный округ     64598
# г. Москва                             56697
# Уральский федеральный округ           54452
# Московская область                    33525
# Дальневосточный федеральный округ     29742
# Name: Занятые в экономике, dtype: int64

# %%
# Количество занятых на разных территориях

# построим гистограмму
sum_employed.plot(x = 'Территория', y = 'Занятые в экономике', kind = 'bar', figsize=(20,8), grid=True, title = 'Количество безработных на разных территориях')

# меняем наименование горизонтальной линии ('X')
plt.xlabel('Территория')
# меняем наименование вертикальной линии ('Y')
plt.ylabel('Занятые в экономике')
plt.show()

# %%
sum_employed.head(2)
# Out:
# Территория
# Российская Федерация             630862
# Центральный федеральный округ    156268
# Name: Занятые в экономике, dtype: int64

# %%
sum_employed.tail(2)
# Out:
# Территория
# Ненецкий автономный округ           188
# Карачаево-Черкесская  Республика    179
# Name: Занятые в экономике, dtype: int64

# %% [markdown]
# По данной таблице РФ опять показывает значительные результаты, но давайте не будем забыть о ее площади. Если мы посмотрим внимательнее, то можем обратить внимание, что количество занятых в РФ значительно больше чем совокупность регионов РФ, которые указаны в нашей выборке, это может быть обусловлено тем, что не по всем субьектам указаны данные.

# %% [markdown]
# **Определение на какой территории минимальный и максимальный процент безработных**

# %%
# считаем долю безработицы по сравнению с общий количеством на территории

data_ter_count_full = data.groupby('Территория')['Численность населения'].sum()

# вычисляем процентное соотношение
percent_data_count_ter_unemployed = sum_unemployed / data_ter_count_full * 100
percent_data_count_ter_unemployed = percent_data_count_ter_unemployed.round(2)
percent_data_count_ter_unemployed = percent_data_count_ter_unemployed.sort_values(ascending=False)
percent_data_count_ter_filter_unemployed = percent_data_count_ter_unemployed.sort_values().head(10)

print('Доля безработицы:')
display(percent_data_count_ter_unemployed)
# Out:
# Доля безработицы:
# Территория
# Республика Северная Осетия - Алания         2590.43
# Республика Ингушетия                          38.64
# Чеченская Республика                          25.96
# Республика Тыва                               18.55
# Республика Дагестан                           15.65
# Кабардино-Балкарская Республика               14.05
# Республика Калмыкия                           13.87
# Карачаево-Черкесская Республика               13.81
# Читинская область                             13.15
# Камчатская область                            12.56
# Северо-Кавказский федеральный округ           11.82
# Республика Бурятия                            11.56
# Карачаево-Черкесская  Республика              11.33
# Забайкальский край                            10.54
# Кабардино-Балкарская  Республика              10.54
# Республика Алтай                              10.41
# Республика Адыгея                             10.34
# Республика Северная Осетия-Алания             10.11
# Курганская область                             9.86
# Южный федеральный округ                        9.42
# Республика Коми                                9.38
# Иркутская область                              8.89
# Астраханская область                           8.61
# Ханты-Мансийский автономный округ              8.60
# Сибирский федеральный округ                    8.50
# Мурманская область                             8.15
# Алтайский край                                 8.12
# Республика Адыгея (Адыгея)                     8.03
# Республика Карелия                             7.92
# Томская область                                7.78
# Республика Саха (Якутия)                       7.71
# Еврейская автономная область                   7.69
# Кемеровская область                            7.69
# Омская область                                 7.68
# Новосибирская область                          7.55
# Амурская область                               7.47
# Волгоградская область                          7.47
# Республика Марий Эл                            7.40
# Приморский край                                7.39
# Дальневосточный федеральный округ              7.35
# Чувашская Республика                           7.32
# Крымский федеральный округ                     7.31
# Сибирский  федеральный округ                   7.30
# Сахалинская область                            7.29
# Ростовская область                             7.22
# Красноярский край                              7.14
# Республика Хакасия                             7.11
# Псковская область                              7.09
# Тамбовская область                             6.92
# Кировская область                              6.88
# Пермская область                               6.87
# Республика Башкортостан                        6.83
# Саратовская область                            6.82
# Смоленская область                             6.76
# Пермский край                                  6.71
# Краснодарский край                             6.71
# Ставропольский край                            6.70
# Оренбургская область                           6.61
# Архангельская область                          6.61
# Хабаровский край                               6.59
# Брянская область                               6.55
# Орловская область                              6.44
# Владимирская область                           6.39
# Уральский федеральный округ                    6.38
# Российская Федерация                           6.38
# Удмуртская Республика                          6.38
# Республика Крым                                6.36
# Калининградская область                        6.35
# Пензенская область                             6.35
# Свердловская область                           6.29
# Ульяновская область                            6.24
# Вологодская область                            6.18
# Челябинская область                            6.17
# Приволжский федеральный округ                  6.12
# Воронежская область                            6.01
# Курская область                                5.94
# Тюменская область                              5.84
# Рязанская область                              5.77
# Камчатский край                                5.68
# Ивановская область                             5.61
# Магаданская область                            5.55
# Нижегородская область                          5.54
# Тверская область                               5.50
# Ярославская область                            5.33
# г. Севастополь                                 5.30
# Костромская область                            5.20
# Республика Мордовия                            5.17
# Республика Татарстан                           5.10
# Северо-Западный федеральный округ              5.08
# Ленинградская область                          4.99
# Новгородская область                           4.98
# Ненецкий автономный округ                      4.95
# Калужская область                              4.81
# Белгородская область                           4.47
# Самарская область                              4.40
# Тульская область                               4.29
# Липецкая область                               4.16
# Центральный федеральный округ                  4.09
# Ханты-Мансийский автономный округ - Югра       4.04
# Ямало-Ненецкий автономный округ                3.85
# Московская область                             3.40
# Чукотский автономный округ                     3.34
# Центральный  федеральный округ                 2.87
# г. Санкт-Петербург                             2.41
# г. Москва                                      1.55
# dtype: float64

# %% [markdown]
# Большое соотношение безработных приходится на Республику Северная Осетия - Алания, возможно это связано с переодическими военными действиями, которые там проходят.

# %% [markdown]
# В разрезе  РФ, у которой были значительно высокие показатели как безработных. По соотношению безработных по всем территориям у РФ 6.38%.

# %%
percent_data_count_ter_unemployed.plot(x = 'Территория', y = 'Безработные', kind = 'bar', figsize=(20,8), grid=True, title = 'Процентное соотношение безработных на разных территориях')
plt.show()

# %% [markdown]
# Теперь сделаем такой же график, только без Руспублики Северная Осетия.

# %%
percent_data_count_ter_unemployed_new = percent_data_count_ter_unemployed[1:]

percent_data_count_ter_unemployed_new.plot(x = 'Территория', y = 'Безработные', kind = 'bar', figsize=(20,8), grid=True, title = 'Процентное соотшошение безработных на разных территориях')
plt.show()

# %%
print(percent_data_count_ter_unemployed.sort_values(ascending=False).head())
# Out:
# Территория
# Республика Северная Осетия - Алания    2590.43
# Республика Ингушетия                     38.64
# Чеченская Республика                     25.96
# Республика Тыва                          18.55
# Республика Дагестан                      15.65
# dtype: float64

# %% [markdown]
# Обратим внимание на Республика Северная Осетия - Алания. Доля безработных составляет 2590,43%
# Давайте проверим почему такая большая доля.

# %%
# выведем суммарное количество за все года по Республика Северная Осетия - Алания
data_alaniya = data[data['Территория'] == 'Республика Северная Осетия - Алания']
data_alaniya_1 = data_alaniya.groupby('Территория').sum()
data_alaniya_1
# Out:
#                                      Численность населения  \
# Территория
# Республика Северная Осетия - Алания                   1704
#
#                                      Занятые в экономике  Безработные  \
# Территория
# Республика Северная Осетия - Алания                 1510        44141
#
#                                      Уровень экономической активности  \
# Территория
# Республика Северная Осетия - Алания                             326.1
#
#                                      Уровень занятости  Уровень безработицы  \
# Территория
# Республика Северная Осетия - Алания              289.0              44067.9
#
#                                      Распределение безработных (до 20 лет)  \
# Территория
# Республика Северная Осетия - Алания                                   25.1
#
#                                      Распределение безработных (от 20 до 29 лет)  \
# Территория
# Республика Северная Осетия - Алания                                        164.1
#
#                                      Распределение безработных (от 30 до 39 лет)  \
# Территория
# Республика Северная Осетия - Алания                                        112.4
#
#                                      Распределение безработных (от 40 до 49 лет)  \
# Территория
# Республика Северная Осетия - Алания                                        107.6
#
#                                      Распределение безработных (от 50 до 59 лет)  \
# Территория
# Республика Северная Осетия - Алания                                         68.8
#
#                                      Распределение безработных (60 и более лет)  \
# Территория
# Республика Северная Осетия - Алания                                        21.9
#
#                                      Распределение занятых (до 20 лет)  \
# Территория
# Республика Северная Осетия - Алания                                6.7
#
#                                      Распределение занятых (от 20 до 29 лет)  \
# Территория
# Республика Северная Осетия - Алания                                    108.7
#
#                                      Распределение занятых (от 30 до 39 лет)  \
# Территория
# Республика Северная Осетия - Алания                                    129.4
#
#                                      Распределение занятых (от 40 до 49 лет)  \
# Территория
# Республика Северная Осетия - Алания                                    133.1
#
#                                      Распределение занятых (от 50 до 59 лет)  \
# Территория
# Республика Северная Осетия - Алания                                     83.8
#
#                                      Распределение занятых (60 и более лет)  \
# Территория
# Республика Северная Осетия - Алания                                    38.3
#
#                                      Численность безработных (до 20 лет)  \
# Территория
# Республика Северная Осетия - Алания                               4757.3
#
#                                      Численность безработных (от 20 до 29 лет)  \
# Территория
# Республика Северная Осетия - Алания                                    17114.5
#
#                                      Численность безработных (от 30 до 39 лет)  \
# Территория
# Республика Северная Осетия - Алания                                     6549.8
#
#                                      Численность безработных (от 40 до 49 лет)  \
# Территория
# Республика Северная Осетия - Алания                                    10721.1
#
#                                      Численность безработных (от 50 до 59 лет)  \
# Территория
# Республика Северная Осетия - Алания                                     3937.9
#
#                                      Численность безработных (60 и более лет)  \
# Территория
# Республика Северная Осетия - Алания                                    1019.1
#
#                                      Численность занятых (до 20 лет)  \
# Территория
# Республика Северная Осетия - Алания                              6.7
#
#                                      Численность занятых (от 20 до 29 лет)  \
# Территория
# Республика Северная Осетия - Алания                                  328.2
#
#                                      Численность занятых (от 30 до 39 лет)  \
# Территория
# Республика Северная Осетия - Алания                                  390.6
#
#                                      Численность занятых (от 40 до 49 лет)  \
# Территория
# Республика Северная Осетия - Алания                                  402.1
#
#                                      Численность занятых (от 50 до 59 лет)  \
# Территория
# Республика Северная Осетия - Алания                                  256.3
#
#                                      Численность занятых (60 и более лет)  \
# Территория
# Республика Северная Осетия - Алания                                 116.0
#
#                                        Год
# Территория
# Республика Северная Осетия - Алания  10033

# %% [markdown]
# Количество безработных по годам в Республика Северная Осетия - Алания

# %%
data_alaniya
# Out:
#                               Территория  Численность населения  \
# 39   Республика Северная Осетия - Алания                    343
# 130  Республика Северная Осетия - Алания                    330
# 221  Республика Северная Осетия - Алания                    315
# 312  Республика Северная Осетия - Алания                    365
# 408  Республика Северная Осетия - Алания                    351
#
#      Занятые в экономике  Безработные  Уровень экономической активности  \
# 39                   285           57                              68.9
# 130                  291           38                              62.2
# 221                  285        43981                              59.3
# 312                  326           38                              68.5
# 408                  323           27                              67.2
#
#      Уровень занятости  Уровень безработицы  \
# 39                57.4                 16.7
# 130               55.0                 11.7
# 221               53.5              44021.0
# 312               61.2                 10.6
# 408               61.9                  7.9
#
#      Распределение безработных (до 20 лет)  \
# 39                                    10.3
# 130                                    1.3
# 221                                   10.8
# 312                                    1.7
# 408                                    1.0
#
#      Распределение безработных (от 20 до 29 лет)  \
# 39                                          28.1
# 130                                         33.7
# 221                                         38.8
# 312                                         28.4
# 408                                         35.1
#
#      Распределение безработных (от 30 до 39 лет)  \
# 39                                          27.7
# 130                                         23.0
# 221                                         14.8
# 312                                         25.5
# 408                                         21.4
#
#      Распределение безработных (от 40 до 49 лет)  \
# 39                                          16.5
# 130                                         26.9
# 221                                         24.3
# 312                                         24.7
# 408                                         15.2
#
#      Распределение безработных (от 50 до 59 лет)  \
# 39                                          14.6
# 130                                         11.3
# 221                                          8.9
# 312                                         12.2
# 408                                         21.8
#
#      Распределение безработных (60 и более лет)  \
# 39                                          2.7
# 130                                         3.8
# 221                                         2.3
# 312                                         7.5
# 408                                         5.6
#
#      Распределение занятых (до 20 лет)  \
# 39                                 2.6
# 130                                1.8
# 221                                0.4
# 312                                1.4
# 408                                0.5
#
#      Распределение занятых (от 20 до 29 лет)  \
# 39                                      21.1
# 130                                     22.5
# 221                                     23.7
# 312                                     21.8
# 408                                     19.6
#
#      Распределение занятых (от 30 до 39 лет)  \
# 39                                      27.2
# 130                                     26.7
# 221                                     26.4
# 312                                     23.6
# 408                                     25.5
#
#      Распределение занятых (от 40 до 49 лет)  \
# 39                                      27.1
# 130                                     26.5
# 221                                     27.9
# 312                                     25.3
# 408                                     26.3
#
#      Распределение занятых (от 50 до 59 лет)  \
# 39                                      11.9
# 130                                     14.9
# 221                                     16.1
# 312                                     19.0
# 408                                     21.9
#
#      Распределение занятых (60 и более лет)  \
# 39                                     10.0
# 130                                     7.7
# 221                                     5.5
# 312                                     8.9
# 408                                     6.2
#
#      Численность безработных (до 20 лет)  \
# 39                                   5.9
# 130                                  0.5
# 221                               4749.9
# 312                                  0.7
# 408                                  0.3
#
#      Численность безработных (от 20 до 29 лет)  \
# 39                                        16.1
# 130                                       13.0
# 221                                    17064.6
# 312                                       11.0
# 408                                        9.8
#
#      Численность безработных (от 30 до 39 лет)  \
# 39                                        15.9
# 130                                        8.9
# 221                                     6509.2
# 312                                        9.9
# 408                                        5.9
#
#      Численность безработных (от 40 до 49 лет)  \
# 39                                         9.5
# 130                                       10.4
# 221                                    10687.4
# 312                                        9.6
# 408                                        4.2
#
#      Численность безработных (от 50 до 59 лет)  \
# 39                                         8.4
# 130                                        4.4
# 221                                     3914.3
# 312                                        4.7
# 408                                        6.1
#
#      Численность безработных (60 и более лет)  \
# 39                                        1.5
# 130                                       1.5
# 221                                    1011.6
# 312                                       2.9
# 408                                       1.6
#
#      Численность занятых (до 20 лет)  Численность занятых (от 20 до 29 лет)  \
# 39                               2.6                                   60.3
# 130                              1.8                                   65.6
# 221                              0.4                                   67.6
# 312                              1.4                                   71.2
# 408                              0.5                                   63.5
#
#      Численность занятых (от 30 до 39 лет)  \
# 39                                    77.7
# 130                                   77.9
# 221                                   75.3
# 312                                   77.1
# 408                                   82.6
#
#      Численность занятых (от 40 до 49 лет)  \
# 39                                    77.4
# 130                                   77.3
# 221                                   79.6
# 312                                   82.6
# 408                                   85.2
#
#      Численность занятых (от 50 до 59 лет)  \
# 39                                    34.0
# 130                                   43.5
# 221                                   45.9
# 312                                   62.0
# 408                                   70.9
#
#      Численность занятых (60 и более лет)   Год
# 39                                   28.6  2001
# 130                                  22.5  2004
# 221                                  15.7  2007
# 312                                  29.1  2009
# 408                                  20.1  2012

# %% [markdown]
# Мы видим, что общее количество безработных составляет 44141, хотя общее количество составляет 1704. Давайте посмотрим данные за каждый год.
#
# В строке 221 мы видим, что за 2007 год у нас значение безработных "огромное" и в связи с этим у нас некорректно формируется доля безработных. Предлагаю удалить строку с этими показателями.

# %%
data = data.drop(index = [221])

# %%
data_alaniya = data[data['Территория'] == 'Республика Северная Осетия - Алания']
data_alaniya_1 = data_alaniya.groupby('Территория').sum()
data_alaniya_1
# Out:
#                                      Численность населения  \
# Территория
# Республика Северная Осетия - Алания                   1389
#
#                                      Занятые в экономике  Безработные  \
# Территория
# Республика Северная Осетия - Алания                 1225          160
#
#                                      Уровень экономической активности  \
# Территория
# Республика Северная Осетия - Алания                             266.8
#
#                                      Уровень занятости  Уровень безработицы  \
# Территория
# Республика Северная Осетия - Алания              235.5                 46.9
#
#                                      Распределение безработных (до 20 лет)  \
# Территория
# Республика Северная Осетия - Алания                                   14.3
#
#                                      Распределение безработных (от 20 до 29 лет)  \
# Территория
# Республика Северная Осетия - Алания                                        125.3
#
#                                      Распределение безработных (от 30 до 39 лет)  \
# Территория
# Республика Северная Осетия - Алания                                         97.6
#
#                                      Распределение безработных (от 40 до 49 лет)  \
# Территория
# Республика Северная Осетия - Алания                                         83.3
#
#                                      Распределение безработных (от 50 до 59 лет)  \
# Территория
# Республика Северная Осетия - Алания                                         59.9
#
#                                      Распределение безработных (60 и более лет)  \
# Территория
# Республика Северная Осетия - Алания                                        19.6
#
#                                      Распределение занятых (до 20 лет)  \
# Территория
# Республика Северная Осетия - Алания                                6.3
#
#                                      Распределение занятых (от 20 до 29 лет)  \
# Территория
# Республика Северная Осетия - Алания                                     85.0
#
#                                      Распределение занятых (от 30 до 39 лет)  \
# Территория
# Республика Северная Осетия - Алания                                    103.0
#
#                                      Распределение занятых (от 40 до 49 лет)  \
# Территория
# Республика Северная Осетия - Алания                                    105.2
#
#                                      Распределение занятых (от 50 до 59 лет)  \
# Территория
# Республика Северная Осетия - Алания                                     67.7
#
#                                      Распределение занятых (60 и более лет)  \
# Территория
# Республика Северная Осетия - Алания                                    32.8
#
#                                      Численность безработных (до 20 лет)  \
# Территория
# Республика Северная Осетия - Алания                                  7.4
#
#                                      Численность безработных (от 20 до 29 лет)  \
# Территория
# Республика Северная Осетия - Алания                                       49.9
#
#                                      Численность безработных (от 30 до 39 лет)  \
# Территория
# Республика Северная Осетия - Алания                                       40.6
#
#                                      Численность безработных (от 40 до 49 лет)  \
# Территория
# Республика Северная Осетия - Алания                                       33.7
#
#                                      Численность безработных (от 50 до 59 лет)  \
# Территория
# Республика Северная Осетия - Алания                                       23.6
#
#                                      Численность безработных (60 и более лет)  \
# Территория
# Республика Северная Осетия - Алания                                       7.5
#
#                                      Численность занятых (до 20 лет)  \
# Территория
# Республика Северная Осетия - Алания                              6.3
#
#                                      Численность занятых (от 20 до 29 лет)  \
# Территория
# Республика Северная Осетия - Алания                                  260.6
#
#                                      Численность занятых (от 30 до 39 лет)  \
# Территория
# Республика Северная Осетия - Алания                                  315.3
#
#                                      Численность занятых (от 40 до 49 лет)  \
# Территория
# Республика Северная Осетия - Алания                                  322.5
#
#                                      Численность занятых (от 50 до 59 лет)  \
# Территория
# Республика Северная Осетия - Алания                                  210.4
#
#                                      Численность занятых (60 и более лет)  \
# Территория
# Республика Северная Осетия - Алания                                 100.3
#
#                                       Год
# Территория
# Республика Северная Осетия - Алания  8026

# %% [markdown]
# Еще рассчитаем доли безработных

# %%
# считаем долю безработицы по сравнению с общий количеством на этой территории (после корректировки количества)

data_count_ter_1 = data.groupby('Территория')['Безработные'].sum()
data_ter_count_full_1 = data.groupby('Территория')['Численность населения'].sum()

# вычисляем процентное соотношение
percent_data_count_ter_1 = data_count_ter_1 / data_ter_count_full_1 * 100

percent_data_count_ter_2 = percent_data_count_ter_1.sort_values(ascending=False).round(2)

print('Доля безработицы:')
display(percent_data_count_ter_2.head())
# Out:
# Доля безработицы:
# Территория
# Республика Ингушетия               38.64
# Чеченская Республика               25.96
# Республика Тыва                    18.55
# Республика Дагестан                15.65
# Кабардино-Балкарская Республика    14.05
# dtype: float64

# %%
print('Максимальная доля безработицы')
print(percent_data_count_ter_2.index[0], '-', percent_data_count_ter_2.max(), '%')
print()
print('Минимальная доля безработицы')
print(percent_data_count_ter_2.index[-1], '-', percent_data_count_ter_2.min(), '%')
# Out:
# Максимальная доля безработицы
# Республика Ингушетия - 38.64 %
#
# Минимальная доля безработицы
# г. Москва - 1.55 %

# %% [markdown]
# Небольшой вывод: после чистки некорректных данных в записях мы рассчитали максимальную и минимальную долю безработицы.
# Максимальная доля безработицы в Республике Ингушетия - 38.64 %
# Минимальная доля безработицы в г.Москве - 1.55 %

# %% [markdown]
# **Вычислить среднее число безработных и занятых (по каждой территории)**

# %% [markdown]
# Создадим отдельную таблицу,в которой отобразим среднее число по регионам по занятым и безработным.

# %%
data_mean_people = pd.DataFrame()

data_mean_people['Среднее значение занятых'] = data.groupby('Территория')['Занятые в экономике'].mean().round(2)
data_mean_people['Среднее значение безработных'] = data.groupby('Территория')['Безработные'].mean().round(2)
display(data_mean_people.head())

axs = data_mean_people.plot.area(figsize=(24, 10), subplots=True)
plt.xticks(rotation=90)
plt.xticks(np.arange(len(data_mean_people)))
plt.show()
# Out:
#                        Среднее значение занятых  Среднее значение безработных
# Территория
# Алтайский край                          1114.67                         98.56
# Амурская область                         399.67                         32.33
# Архангельская область                    605.44                         42.89
# Астраханская область                     477.00                         45.00
# Белгородская область                     747.33                         35.00

# %% [markdown]
# Давайте отдельно выясним резкий и единственный рост в графиках занятых и безработных.

# %%
people_1 = data.groupby('Территория')['Занятые в экономике'].mean().round(2).sort_values(ascending=False)
people_2 = data.groupby('Территория')['Безработные'].mean().round(2).sort_values(ascending=False)

print('Среднее число занятые')
print(data.loc[0, 'Территория'], '-', people_1[0])
print('Среднее число безработные')
print(data.loc[0, 'Территория'], '-', people_2[0])
# Out:
# Среднее число занятые
# Российская Федерация - 70095.78
# Среднее число безработные
# Российская Федерация - 4778.89

# %% [markdown]
# Мы видим, что у РФ большое количество как занятых, так и безработных, и как писалось ранее это можно аргументировать тем, что достаточно много субъектов входит в ее состав. Поэтому и на графике мы видим значительный рост показателей в отличии от других.
#
# Посчитаем среднее количество безработных по каждому году, хоть это и не прописано в нашем влане, но давайте взглянем на эти данные.

# %%
data_mean_people_years = pd.DataFrame()

data_mean_people_years['Среднее значение занятых'] = data.groupby('Год')['Занятые в экономике'].mean().round(2)
data_mean_people_years['Среднее значение безработных'] = data.groupby('Год')['Безработные'].mean().round(2)
display(data_mean_people_years)

axs = data_mean_people_years.plot.area(figsize=(24, 10), subplots=True)
plt.xticks(rotation=90)
plt.show()
# Out:
#       Среднее значение занятых  Среднее значение безработных
# Год
# 2001                   2157.31                        214.62
# 2004                   2253.79                        189.83
# 2007                   2361.46                        152.94
# 2009                   2296.60                        210.51
# 2012                   2345.63                        134.89
# 2013                   2340.48                        135.09
# 2015                   2296.17                        134.75
# 2017                   2314.89                        126.62
# 2019                   2308.29                        110.44

# %% [markdown]
# Среднее значение занятых людей в стабольном состоянии из года в год. А вот безработица из года в год уменьшается с небольшими скачками.

# %% [markdown]
# **Выделить ТОП-5 территорий по безработным и занятым**

# %%
# выведем ТОП 5 территорий с занятыми

top_5_data_mean_people_employed = data.groupby('Территория')['Занятые в экономике'].mean().sort_values(ascending=False).head(5).round(2)

print(top_5_data_mean_people_employed)
# Out:
# Территория
# Российская Федерация              70095.78
# Центральный  федеральный округ    20723.00
# Центральный федеральный округ     19533.50
# Приволжский федеральный округ     14603.67
# Сибирский федеральный округ        8939.38
# Name: Занятые в экономике, dtype: float64

# %%
# выведем ТОП 5 территорий с безработными

top_5_data_mean_people_unemployed = data.groupby('Территория')['Безработные'].mean().sort_values(ascending=False).head(5).round(2)

print(top_5_data_mean_people_unemployed)
# Out:
# Территория
# Российская Федерация             4778.89
# Приволжский федеральный округ     952.22
# Южный федеральный округ           833.67
# Центральный федеральный округ     833.38
# Сибирский федеральный округ       830.00
# Name: Безработные, dtype: float64

# %% [markdown]
# Построение столбчатой диаграммы с количеством занятых (по возрастным категориям)

# %%
data_2 = data[['Численность занятых (до 20 лет)', 'Численность занятых (от 20 до 29 лет)',
               'Численность занятых (от 30 до 39 лет)', 'Численность занятых (от 40 до 49 лет)',
               'Численность занятых (от 50 до 59 лет)', 'Численность занятых (60 и более лет)']].sum()
display(data_2)
# Out:
# Численность занятых (до 20 лет)            1040.5
# Численность занятых (от 20 до 29 лет)    411317.8
# Численность занятых (от 30 до 39 лет)    499267.4
# Численность занятых (от 40 до 49 лет)    495785.5
# Численность занятых (от 50 до 59 лет)    384924.5
# Численность занятых (60 и более лет)      89637.2
# dtype: float64

# %%
data_2 = data_2.plot()
plt.xticks(rotation=90)
plt.show()

# %%
data_3 = data[['Численность безработных (до 20 лет)', 'Численность безработных (от 20 до 29 лет)',
               'Численность безработных (от 30 до 39 лет)', 'Численность безработных (от 40 до 49 лет)',
               'Численность безработных (от 50 до 59 лет)', 'Численность безработных (60 и более лет)']].sum()
display(data_3)
# Out:
# Численность безработных (до 20 лет)           8361.2
# Численность безработных (от 20 до 29 лет)    44508.9
# Численность безработных (от 30 до 39 лет)    29345.9
# Численность безработных (от 40 до 49 лет)    26077.8
# Численность безработных (от 50 до 59 лет)    18139.6
# Численность безработных (60 и более лет)      3190.6
# dtype: float64

# %%
data_3 = data_3.plot()
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# В нашей ТОП-5 выборке привалирует количество занятых людей во всех возрастных категориях, кроме людей до 20 лет и людей старше 60 лет. Объяснить это можно тем, что не все молодое поколение хочет работать, а более приклонный возраст или не может работать в связи с ограниченными возможностями или могут просто не доживать до этого возраста.

# %% [markdown]
# **Проверка гипотез**

# %% [markdown]
# В финальной части нам необходимо проверить три гипотезы:
#
#
#
#
#
#
#
# *   в каждой из возрастных категорий среднее значение занятых идентично со средним значением безработныхэ
# *   среднее значение безработных (в возрасте от 40 до 49 лет) в Брянской области одинаково со средним значением безработных возрасте до 20 лет
#
#
# *   средний показатель безработицы в 2009 и 2019 году одинаков.

# %% [markdown]
# **Гипотеза: в каждой из возрастных категорий среднее значение занятых идентично среднему значению безработных**

# %% [markdown]
# Подготовим выгрузку для проверки гипотезы

# %%
# сумма занятых до 20
employed_aged_20 = data['Численность занятых (до 20 лет)'].sum().round()
#print("Сумма занятых до 20 лет -", employed_aged_20)
# сумма занятых от 20 до 29 лет
employed_aged_20_to_29 = data['Численность занятых (от 20 до 29 лет)'].sum().round()
#print("Сумма занятых от 20 до 29 лет -", employed_aged_20_to_29)
# сумма занятых от 30 до 39 лет
employed_aged_30_to_39 = data['Численность занятых (от 30 до 39 лет)'].sum().round()
#print("Сумма занятых от 30 до 39 лет -", employed_aged_30_to_39)
# сумма занятых от 40 до 49 лет
employed_aged_40_to_49 = data['Численность занятых (от 40 до 49 лет)'].sum().round()
#print("Сумма занятых от 40 до 49 лет -", employed_aged_40_to_49)
# сумма занятых от 50 до 59 лет
employed_aged_50_to_59 = data['Численность занятых (от 50 до 59 лет)'].sum().round()
#print("Сумма занятых от 50 до 59 лет -", employed_aged_50_to_59)
# сумма занятых с возрастом 60 и более лет
employed_aged_60_or_more = data['Численность занятых (60 и более лет)'].sum().round()
#print("Сумма занятых в возрасте от 60 и более лет -", employed_aged_60_or_more)
#print()

# сумма безработных до 20
unemployed_aged_20 = data['Численность безработных (до 20 лет)'].sum().round()
#print("Сумма безработных до 20 лет -", unemployed_aged_20)
# сумма безработных от 20 до 29 лет
unemployed_aged_20_to_29 = data['Численность безработных (от 20 до 29 лет)'].sum().round()
#print("Сумма безработных от 20 до 29 лет -", unemployed_aged_20_to_29)
# сумма безработных от 30 до 39 лет
unemployed_aged_30_to_39 = data['Численность безработных (от 30 до 39 лет)'].sum().round()
#print("Сумма безработных от 30 до 39 лет -", unemployed_aged_30_to_39)
# сумма безработных от 40 до 49 лет
unemployed_aged_40_to_49 = data['Численность безработных (от 40 до 49 лет)'].sum().round()
#print("Сумма безработных от 40 до 49 лет -", unemployed_aged_40_to_49)
# сумма безработных от 50 до 59 лет
unemployed_aged_50_to_59 = data['Численность безработных (от 50 до 59 лет)'].sum().round()
#print("Сумма безработных от 50 до 59 лет -", unemployed_aged_50_to_59)
# сумма безработных с возрастом 60 и более лет
unemployed_aged_60_or_more = data['Численность безработных (60 и более лет)'].sum().round()
#print("Сумма безработных в возрасте от 60 и более лет -", unemployed_aged_60_or_more)

# %% [markdown]
# Для проверки гипотезы "в каждой из возрастных категорий безработных больше, чем занятых" в качестве нулевой и альтернативной гипотезы мы взяли следующее: H0: количество занятых и безработных одинаковые H1: количество занятых и безработных различно.

# %%
employed_under_20 = data['Численность занятых (до 20 лет)']
unemployed_under_20 = data['Численность безработных (до 20 лет)']

print('Среднее количество занятых (до 20 лет) -', data['Численность занятых (до 20 лет)'].mean())
print('Среднее количество безработных (до 20 лет) -', data['Численность безработных (до 20 лет)'].mean())
print()

alpha = .05 # критический уровень статистической значимости
# если p-value окажется меньше него - отвегнем гипотезу

results = st.ttest_ind(
    employed_under_20,
    unemployed_under_20)

print('p-значение: ', results.pvalue)

if results.pvalue < alpha:
    print("Отвергаем нулевую гипотезу")
else:
    print("Не получилось отвергнуть нулевую гипотезу")
# Out:
# Среднее количество занятых (до 20 лет) - 1.2566425120772946
# Среднее количество безработных (до 20 лет) - 10.09806763285024
#
# p-значение:  3.947563510971562e-11
# Отвергаем нулевую гипотезу

# %% [markdown]
# Результат говорит о том, что нулевая гипотеза  отвергается.

# %%
employed_aged_30_to_39 = data['Численность занятых (от 30 до 39 лет)']
unemployed_aged_30_to_39 = data['Численность безработных (от 30 до 39 лет)']

print('Среднее количество занятых (от 30 до 39 лет) -', data['Численность занятых (от 30 до 39 лет)'].mean())
print('Среднее количество безработных (от 30 до 39 лет) -', data['Численность безработных (от 30 до 39 лет)'].mean())
print()

alpha = .05 # критический уровень статистической значимости
# если p-value окажется меньше него - отвегнем гипотезу

results = st.ttest_ind(
    employed_aged_30_to_39,
    unemployed_aged_30_to_39)

print('p-значение: ', results.pvalue)

if results.pvalue < alpha:
    print("Отвергаем нулевую гипотезу")
else:
    print("Не получилось отвергнуть нулевую гипотезу")
# Out:
# Среднее количество занятых (от 30 до 39 лет) - 602.9799516908212
# Среднее количество безработных (от 30 до 39 лет) - 35.441908212560385
#
# p-значение:  1.3006211981022801e-15
# Отвергаем нулевую гипотезу

# %% [markdown]
# Результат говорит о том, что нулевая гипотеза отвергается.

# %%
employed_aged_40_to_49 = data['Численность занятых (от 40 до 49 лет)']
unemployed_aged_40_to_49 = data['Численность безработных (от 40 до 49 лет)']

print('Среднее количество занятых (от 40 до 49 лет) -', data['Численность занятых (от 40 до 49 лет)'].mean())
print('Среднее количество безработных (от 40 до 49 лет) -', data['Численность безработных (от 40 до 49 лет)'].mean())
print()

alpha = .05 # критический уровень статистической значимости
# если p-value окажется меньше него - отвегнем гипотезу

results = st.ttest_ind(
    employed_aged_40_to_49,
    unemployed_aged_40_to_49)

print('p-значение: ', results.pvalue)

if results.pvalue < alpha:
    print("Отвергаем нулевую гипотезу")
else:
    print("Не получилось отвергнуть нулевую гипотезу")
# Out:
# Среднее количество занятых (от 40 до 49 лет) - 598.7747584541063
# Среднее количество безработных (от 40 до 49 лет) - 31.494927536231884
#
# p-значение:  8.637966046337676e-16
# Отвергаем нулевую гипотезу

# %% [markdown]
# Результат говорит о том, что нулевая гипотеза отвергается.

# %%
employed_aged_50_to_59 = data['Численность занятых (от 50 до 59 лет)']
unemployed_aged_50_to_59 = data['Численность безработных (от 50 до 59 лет)']

print('Среднее количество занятых (от 50 до 59 лет) -', data['Численность занятых (от 50 до 59 лет)'].mean())
print('Среднее количество безработных (от 50 до 59 лет) -', data['Численность безработных (от 50 до 59 лет)'].mean())
print()

alpha = .05 # критический уровень статистической значимости
# если p-value окажется меньше него - отвегнем гипотезу

results = st.ttest_ind(
    employed_aged_50_to_59,
    unemployed_aged_50_to_59)

print('p-значение: ', results.pvalue)

if results.pvalue < alpha:
    print("Отвергаем нулевую гипотезу")
else:
    print("Не получилось отвергнуть нулевую гипотезу")
# Out:
# Среднее количество занятых (от 50 до 59 лет) - 464.8846618357488
# Среднее количество безработных (от 50 до 59 лет) - 21.907729468599037
#
# p-значение:  1.3844343258107276e-15
# Отвергаем нулевую гипотезу

# %%
employed_aged_60_or_more = data['Численность занятых (60 и более лет)']
unemployed_aged_60_or_more = data['Численность безработных (от 50 до 59 лет)']

print('Среднее количество занятых (60 и более лет) -', data['Численность занятых (60 и более лет)'].mean())
print('Среднее количество безработных (от 50 до 59 лет) -', data['Численность безработных (от 50 до 59 лет)'].mean())
print()

alpha = .05 # критический уровень статистической значимости
# если p-value окажется меньше него - отвегнем гипотезу

results = st.ttest_ind(
    employed_aged_60_or_more,
    unemployed_aged_60_or_more)

print('p-значение: ', results.pvalue)

if results.pvalue < alpha:
    print("Отвергаем нулевую гипотезу")
else:
    print("Не получилось отвергнуть нулевую гипотезу")
# Out:
# Среднее количество занятых (60 и более лет) - 108.25748792270531
# Среднее количество безработных (от 50 до 59 лет) - 21.907729468599037
#
# p-значение:  6.963605355581411e-11
# Отвергаем нулевую гипотезу

# %% [markdown]
# После проверки гипотезы по всем возрастным категория мы можем сделать единый вывод - среднее количество занятых длюдей не одинаково со средним количество безработных.

# %% [markdown]
# **Гипотеза: среднее значение безработных (в возрасте от 40 до 49 лет) в Брянской области одинаково со средним значением безработных возрасте до 20 лет**

# %%
data_bryansk = data.query('Территория == "Брянская область"')
#display(data_bryansk.head())

# %%
# сумма безработных Брянская область от 40 до 49 лет
unemployed_aged_40_to_49_bryansk = data_bryansk['Численность безработных (от 40 до 49 лет)'].sum().round(2)
#display(unemployed_aged_40_to_49_bryansk)
#print()
# сумма безработных до 20 лет
unemployed_aged_20_bryansk = data_bryansk['Численность безработных (до 20 лет)'].sum().round(2)
#display(unemployed_aged_20_bryansk)

# %%
unemployed_under_40_bryansk = data['Численность безработных (от 40 до 49 лет)']
unemployed_under_20_bryansk = data['Численность безработных (до 20 лет)']

print('Среднее количество безработных (от 40 до 49 лет) -', data['Численность безработных (от 40 до 49 лет)'].mean())
print('Среднее количество безработных (до 20 лет) -', data['Численность безработных (до 20 лет)'].mean())
print()

alpha = .05 # критический уровень статистической значимости
# если p-value окажется меньше него - отвегнем гипотезу

results = st.ttest_ind(
    employed_aged_60_or_more,
    unemployed_aged_60_or_more)

print('p-значение: ', results.pvalue)

if results.pvalue < alpha:
    print("Отвергаем нулевую гипотезу")
else:
    print("Не получилось отвергнуть нулевую гипотезу")
# Out:
# Среднее количество безработных (от 40 до 49 лет) - 31.494927536231884
# Среднее количество безработных (до 20 лет) - 10.09806763285024
#
# p-значение:  6.963605355581411e-11
# Отвергаем нулевую гипотезу

# %% [markdown]
# Количество занятых в разы больше безработных - гипотеза отвергнута.

# %% [markdown]
# **Гипотеза: средний показатель безработицы в 2009 и 2019 году одинаков**

# %%
data_unemployed_2009 = data.query('Год == 2009')
#display(data_unemployed_2009.head())
#print()
data_unemployed_2019 = data.query('Год == 2019')
#display(data_unemployed_2019.head())

# %%
# сумма безработных 2009
unemployed_year_2009 = data_unemployed_2009['Безработные'].count()
#display(unemployed_year_2009)
#print()
# сумма безработных 2019
unemployed_year_2019 = data_unemployed_2019['Безработные'].count()
#display(unemployed_year_2019)

# %% [markdown]
# Средний показатель безработицы за 2009 и 2019 года примерно одинаковый.

# %%
unemployed_2009 = unemployed_year_2009
unemployed_2019 = unemployed_year_2019

print('Среднее количество безработных в 2009 -', unemployed_2009)
print('Среднее количество безработных в 2019 -', unemployed_2019)
print()

alpha = .05 # критический уровень статистической значимости
# если p-value окажется меньше него - отвегнем гипотезу

results = st.ttest_ind(
    unemployed_2009,
    unemployed_2019)

print('p-значение: ', results.pvalue)

if results.pvalue < alpha:
    print("Отвергаем нулевую гипотезу")
else:
    print("Не получилось отвергнуть нулевую гипотезу")
# Out:
# Среднее количество безработных в 2009 - 91
# Среднее количество безработных в 2019 - 94
#
# p-значение:  nan
# Не получилось отвергнуть нулевую гипотезу

# %% [markdown]
# Средний показатель безработицы за 2019 года преобладает.

# %% [markdown]
# Дополнительная информация

# %% [markdown]
# **Подготовка документации по библиотекам**
#
# **pandas** - это библиотека Python для обработки и анализа структурированных данных, её название происходит от «panel data» («панельные данные»). Панельными данными называют информацию, полученную в результате исследований и структурированную в виде таблиц. Для работы с такими массивами данных и создан Pandas.
#
# **matplotlib** - это библиотека на языке Python для визуализации данных. В ней можно построить двумерные (плоские) и трехмерные графики.
#
# **matplotlib.pyplot** - самый высокоуровневый интерфейс с набором команд и функций. В высокоуровневом интерфейсе все автоматизировано, поэтому его проще всего осваивать новичкам.
#
# **seaborn** - библиотека для создания статистических графиков на Python. Она построена на основе matplotlib и тесно интегрируется со структурами данных pandas. Seaborn помогает вам изучить и понять данные. Его функции построения графиков работают с датасетами и выполняют все необходимы преобразования для создания информативных графиков.
#
# **numpy** - библиотека с открытым исходным кодом для языка программирования Python. Возможности: поддержка многомерных массивов (включая матрицы); поддержка высокоуровневых математических функций, предназначенных для работы с многомерными массивами.
#
# **scipy** - это еще одна научная библиотека, на базе которой реализована SciPy. Ее особенность — использование специальных структур данных — многомерных массивов, в которых хранится информация. С этим типом данных также работает SciPy. NumPy содержит данные массивов и такие операции, как индексация, сортировка и т. д., а SciPy состоит из числового кода.
#
# **warnings** - полезен, когда необходимо предупредить пользователя о каком-либо условии в программе и это условие не требует создания исключения и завершения программы. Например, может возникнуть необходимость выдать предупреждение, когда программа использует устаревший модуль.

# %% [markdown]
# **Общий вывод**
# Сделаем вывод по проделанной работе. После тщательной подготовки файла с данными мы провели диагностику.
#
# В финальной части нам необходимо проверить три гипотезы:
#
# • в каждой из возрастных категорий среднее значение занятых идентично со средним значением безработных
# При проверке данной гипотезы мы выяснили, что не по одной возрастной категории нет совпадений в средних значениях между занятыми и безработными.
#
# • среднее значение безработных (в возрасте от 40 до 49 лет) в Брянской области одинаково со средним значением безработных возрасте до 20 лет
# Так же нулевая гипотеза опровергнута:
# Среднее количество безработных (от 40 до 49 лет) - 598.7747584541063
# Среднее количество безработных (до 20 лет) - 10.09806763285024
#
# • средний показатель безработицы в 2009 и 2019 году одинаков
# Данная гипотеза была доказана, значения равны с допустимой погрешностью.
